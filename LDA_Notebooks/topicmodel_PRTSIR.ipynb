# %% [markdown]
# ## Topic Modeling with pyLDAvis
# -kernel = env mypython

# %%
#Import Libraries
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu

import os

import pyLDAvis.gensim
import pickle 
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

#hide warnings
import warnings
warnings.filterwarnings('ignore')

# %%
data = dataiku.Dataset("JIRA_filteredBy_Fixed_PRTSIR")
df = data.get_dataframe()
df.head()
# Out:
#             key fields.resolution.name                         fields.description_cleaned                             fields.summary_cleaned
# 0   PRTSIR-1554                  Fixed  perform sky point run notice dv04 point result...                   dv04 erratic point sky point run
# 1  PRTSIR-12931                  Fixed  start system dv07 appear local mode acu e stop...         ape2 dv07 e stop acu local mode not change
# 2   PRTSIR-3363                  Fixed  last occurrence noformat 10t19:05:51.074 info ...                           bl corr observation fail
# 3   PRTSIR-1212                  Fixed  run -b -s --fail-- start end 07t23:57:20 08t00...  aos cm02 unexpectedly fail retrieve component ...
# 4  PRTSIR-10781                  Fixed  dv12 show high trec tsys value observe band no...  aos64 bl_pr#1 da53 ex dv12 fe69 high trec tsys...

# %%
#drop missing values
df = df.dropna()
len(df)
# Out:
# 187

# %%
#extract text from summary_cleaned
summary_corpus = df['fields.summary_cleaned'].tolist()
# Corpus as a list of text documents
#summary_corpus = [' '.join(text.split()) for text in summary_corpus]
summary_corpus
# Out:
# ['dv04 erratic point sky point run',
#  'ape2 dv07 e stop acu local mode not change',
#  'bl corr observation fail',
#  'aos cm02 unexpectedly fail retrieve component control cm02 antinterferometrycontroller',
#  'aos64 bl_pr#1 da53 ex dv12 fe69 high trec tsys value pol band lo pa optimisation failure cause clna oscillation',
#  'aos wca7 sn cm04 fe15 fail lock band ghz',
#  'aos bl da58 fe15 band high trx cryogenic temperature spec',
#  'datum cluster master node time problem cdpnode',
#  'aos csv aca calsurvey uid://a002 x7a1660 x4bb no atmcal result',
#  'aos handover dv06 servo failure',
#  'aos bl da63 compressor go unnoticed fe warm',
#  'qa2 signal teardrop dv16 fe37 band spw cca5',
#  'ape2 da58 flagged temp band acd issue',
#  'aos bl dv17 fe-47 frontend bus problem band band little',
#  'aos handover dv04 lo2bbpair2 not visible canbus',
#  'ape2 bl da58 wrong tsys trx pol band little',
#  'aos acacorr not load configuration correlator',
#  'ape2 da50 node not respond az axis',
#  'aos handover dv02 hvac alarm',
#  'aos dv07 fe wca3 not lock',
#  'aos bl da52 antenna show high temperature trec pol bb_1,2,4 band',
#  'ape1 aca powon diag status error',
#  'aos fire system cheetah controller not functional',
#  'aos bl error ssr array025-bl standardinterferometry expandsourcequeries no query result phase calibration not pass selection criterium exit',
#  'aos dv16 acu mmc communication error',
#  'aos bl dv11 datum flag ambient hot load temperature incorrect',
#  'aos weather station tb2 pressure reading much noisy station particularly daytime hour',
#  'ape2 bl dv02 psa device sw not operational state',
#  'aos dv06 signal lose drxs',
#  'aos da59 repeatedly problem atmcals acds stick park1 position',
#  'aos handover da45 dgck dtx stop',
#  'aos dv12 lock problem band',
#  'aos dv09 no coherence wca lock failure cause camb error',
#  'cm07 iccu low system pressure p dynamic mpa',
#  'aos aca science sb fail validation spectral window',
#  'c8 handover dv18 acd not align',
#  'aos acds antenna flag incorrect hot ambient load temp',
#  'aos handover dv01 fend power amplifier pol low cryostat problem',
#  'aos archive tmcdb blobber6 container go',
#  'aos da58 fe13 not lock band ghz',
#  'aos cm04 fe43 show wrong trx cryostat issue band service',
#  'aos da47 acu keyboard not work',
#  'aos aca importerror no module name shadowingchecker sb name aca b3-ra',
#  'ape2 dv22 fe68 band7 phase rms bandpass phase cal pol',
#  'aos_bl_pr1 dv12 band trec negative temperatures',
#  'aos aca bl corr interactive focus sb projec 187.csv fail',
#  'aos bl no point result consider fatal',
#  'domestic water pumps aos tb system fail operation',
#  'ape2 handover dv02 not lock band',
#  'aos bl error invoke observe mode function camb error da51',
#  'aos dv05 fe01 low power level lo power amplifier vd steps band',
#  'aos da49 high trec polx band',
#  'aos da64 fail lock band',
#  'aos da47 rec cabin temperature high chiller connection fault',
#  'aos dv11 ramp receiver cabin interlock set',
#  'aos bl dv06 ifproc0 n show no current supply rail no very low power detector',
#  'ape1 bl da63 cryostat degradation affect fe performance',
#  'ape2 da49 mount az encoder reference timeout',
#  'ape1 da44 fe high temperature cryo stage',
#  'ape2 bl pm01 not lock band8',
#  'aos aca baseband0 center frequency ghz not completely band3',
#  'aos da53 pol total power spike ifproc n',
#  'aos_bl_pr1 da56 band bb_1 trec negative temperature',
#  'aos64 bl pm04 flagged atmosphere datum',
#  'aos bl da46 intermittent lock band',
#  'aos handover da55 psd turn high temperature',
#  'aos bl da43 not lock band',
#  'aos da60 ifproc problem trx bb_3,4 pol band',
#  'ape2 blc phase subscan setup error bb aborting',
#  'ape2 clo bl aca antenna lorr trouble synchronize',
#  'aos da59 b6 not lock',
#  'aos_aca_pr2 failed receive correlation datum aca cdpcs',
#  'aos aca timed wait second correlator calibration sub scan',
#  'aos da52 inconsistent delay offsets bb1 bb2',
#  'aos64_bl dv17 fe47 wca3 lock problem lo1 107.896922[ghz',
#  'tfint script fail python exception',
#  'aos bl correlator timeout',
#  'aos bl dv21 fe08 cryostat get degrade power cycle',
#  'ape1 bl da46 camb error channel node 0x0 mount go stop',
#  'aos telcal acc cppcontainer2 suddenly crash current sb',
#  'ape1 bl dv22 fe08 high trx band',
#  'aos shiftlog hang start new shift',
#  'aos da61 subreflector suddenly sr not ready',
#  'aos pr+cvr not operational',
#  'aos bl dv15 lorr trouble synchronize',
#  'aos handover da45 not dtxs operaitonal state operation',
#  'aos bl da42 problem lock band ghz lo1 freq',
#  'aos bl_pr2 da59 intermittent lock issue band',
#  'aos dv21 band not lock ghz skyfreq',
#  'dv08 dtxbbpr2 mhz unlock bits b c',
#  'dv18 de ds monitor clear dichotomy',
#  'aos dv25 receiver cabin temperature high',
#  'aos da59 high receiver temp see band',
#  'aos blcorr da63 mount go stop science manual execution fail',
#  'pm02 felab fe29 installation fe device stop not start eng verification',
#  'aos bl da51 fail lock b3 ghz lo1 freq',
#  'da57 fe43 birdie band pol x',
#  'da49 large delay error x polarization deg baseband',
#  'aos dv05 fend negative receiver temperature polarization bbp band potential acd issue',
#  'pm-02 el brake system reduction gear strange noise',
#  'aos64 bl da48 fe56 pol tsys trx erratic value band',
#  'dv02 hvac alarm outside unit service',
#  "aos dv23 doesn't lock band",
#  'aos pm04 wca7 not lock b7',
#  'ape1 cm11 show abnormal tsys trx behaviour pol bbprs severan scan band',
#  'aos bl da55 antenna wvr not operational show bad number quicklook',
#  'dv22 show strange delay band',
#  'ape2 dv13 mount not set mount device operational',
#  'aos pr1 bl band3 da57 pol bbpairs show no coherence',
#  'aos early science aca corr cm04 fe06 not lock band ghz lo1',
#  'ape1 bl da53 fe12 high trx band',
#  'aos_aca_pr2 observation not provide little starttime',
#  'ape2 aca7m cm01 fe33 wca4 not lock',
#  'aos da63 elevation axis motor fault',
#  'aca no point phase rms result bad parameter calculation reduce chi square',
#  'aos pr1 bl sbex dv02 band3 not lock lo1=107.48 ghz',
#  'aos dv16 acd-53 show high hot load ambient temperature get stick park',
#  'ape2 aca cm04 bad offsetdelays pol x',
#  'aos bl band da65 show negative trx baseband band pol x pol tsys shape suspicious',
#  'aos aca sbex fail not calibrate correlator',
#  'ape1 da59 dtxbbpr1 bad te mhz unlock',
#  'aos bl da53 antenna show no coherence bbpairs noisy coherence bbpair1',
#  'da44 az axis go shutdown state tiltmetercal',
#  'ape1 aca cm12 fe67 not locked band',
#  'aos acacorr cm06 mount azimuth axis suddenly go shutdown',
#  'ape1 bl da65 flagged datum bbpr3 pol band',
#  'ape2 bl dv09 problems cross correlation power jump',
#  'aos dv10 antenna not lock band',
#  'aos bl cm01 bbpr2 show artificial pattern auto- cross correlation',
#  'aos bl da45 tsys show negative temperature band bbpr3 polarization',
#  'aos handover bl reinitialization child process fail value failed initalizing calc process usually iers issue',
#  'dv07 250mhz spike bb3 pol',
#  'ape2 aca tp pm04 not lock request frequency bands test',
#  'qa0 phase time drift antenna cm11',
#  'aos da49 el axis go shutdown',
#  'aos dv22 buffer tank pressure low little mpa',
#  'ape1 da56 shutter undeterminated position',
#  'da64 acu power supply failure',
#  'ape1 bl dv01 fe61 failed lock band little different lo1 freq',
#  'aos64 bl dv23 fe21 high tsys trx value pol',
#  'ape1 dv02 az drive go shutdown servo failure amplifier failure',
#  'aos dv06 bbpr0 bbpr2 polarization noisy no cross correlation',
#  'ape1 bl da63 shutter position undetermined',
#  'aos dv12 fe13 antenna not lock band',
#  'aos2 pr4 delayserver crash',
#  'aos bl da52 timeout wait connection ifproc datareceiver',
#  'aos64 bl da43 fe15 band trx significantly high rest array',
#  'aos da61 subreflector suddenly sr not ready',
#  'ape2 da52 fe09 high atm temp bb pol x band band cryostat degradation',
#  'aos dv20 fe19 wca3 not lock ghz lo1',
#  'aos_aca_pr4 fail start flow transference totalpowerstream5 totalpowerdataflow',
#  'aos bl dv19 lock intermittently band',
#  'ape1 bl pm01 el axis go shut el encoder fault',
#  'ape2 bl da52 mount el encoder hall sens inconsistency',
#  'shilflog tool mmex interferometric pointing command not appear subject',
#  'aos bl da47 fend band6 yellow triangle subscan fail lock wca6',
#  'aos dv04 dv07 dv10 dv11 dv13 dv17 dv21 dv23 mount displacement sensor redout error',
#  'da45 acd wrong temp communication issue',
#  'ape1 bl mmex dv17 feps',
#  'aos aca suddenly aca cdpmif cppcontainer crash observation',
#  'tfsd da59 pol-0 bbp0,p1,p2 saturate',
#  'ape2 bl da59 ns delay bb1',
#  'ape1 aca7 cm07 not source',
#  'ape2 aca cm08 not lock band',
#  'aos_bl_pr1 follow ltas not configure channel',
#  'aos aca7 cm04 fe21+fe43+fe45 high tsys ans trec value k stage temperature high',
#  'aos bl atmospheric scan show tsys low trx antenna offline reduction show correct result',
#  'aos bl dv09 dv10,dv11 very low signal band',
#  'aos llc problem dv17 da64 dv19 dv20',
#  'aos cm06 fe46 tsys trx high value',
#  'aos pm04 not lock band3',
#  'blc flag datum binary flag',
#  'aos bl pr1 handover bl array not create antenna involve miss',
#  'ape2 aca_7 cm12 extremely high phaserms vs baseline value bbp band pol',
#  'aos cycle test aca subarrays tp array fail timed wait second correlator archive sub scan',
#  'aos dv09 not specify total power processor consume datum antenna',
#  'aos bl da43 psa go',
#  'aos cm08 fend warm cryocooler stage temp k k',
#  'aos_handover da60 unable open shutter',
#  'acacorr q0 cip#3 issue cause platforming',
#  'ape2 bl da64 fe29 band high tsys trx pol bbs',
#  'aos control dmc2 container suddenly go problem try instantiate drxbbpr1 antenna',
#  'ape2 aca pm04 not lock band lo1 frequency 806.218650[ghz',
#  'aos2 pr4 pm02 antenna not lock b3,6,7',
#  'dv09 fe19 b7 locking issue lack total power',
#  'aos_aca_pr2 fail start flow transference totalpowerstream6 totalpowerdataflow',
#  'aos bl da47 fe-22 cca7 sideband swap pol not detect signal path test']

# %%
#extract text from description_cleaned
description_corpus = df['fields.description_cleaned'].tolist()
# Corpus as a list of text documents
#description_corpus = [' '.join(text.split()) for text in description_corpus]
description_corpus
# Out:
# ['perform sky point run notice dv04 point result consistent pointingn model scatter arcsec attach quicklook plot bad_pointing_quicklook_x43-dv04.png|thumbnail suggest initially assign ir ticket science investigate',
#  'start system dv07 appear local mode acu e stop active remove e stop try utility mode restart script crash control dv07 cppcontainer crash good antenna pass inaccessible state far -p try operation again fail way take antenna array czamorano check antenna end declare operation',
#  'last occurrence noformat 10t19:05:51.074 info control array003 subscan intent on_source take second start 10t19:06:03.450 info control acc javacontainer orb status connectionthreadsused=14 lose calls=0 requestqueuemaxusepercent=5 poa componentpoa_control array002 10t19:06:12.607 error control array003 error invoke observe mode function type=10410 code=0 message=\'problem complete subscan 10t19:06:12.606 error control array003 correlator resource conflict type=20000 code=8 cause=\'data cluster master node time 10t19:06:12.629 info control array003 waiting second current subscan complete 10t19:06:32.179 error control array003 operation timeout type=10000 code=22 message=\'the subscan not stop second check timeout long subscan duration observe mode shutdown cleanup function array=\'array003 alma controlexceptions timeoutex idl alma controlexceptions timeoutex:1.0 alma controlexceptions.wrappers acsjtimeoutex.totimeoutex(acsjtimeoutex.java:135 alma control observingmodes observingmodeutilities.throwtimeoutex(observingmodeutilities.java:319 alma control observingmodes observingmodecore.throwtimeoutex(observingmodecore.java:511 alma control observingmodes observingmodecore.throwtimeoutex(observingmodecore.java:504 alma control observingmodes observingmodebaseimpl.stopobserving(observingmodebaseimpl.java:356 alma control observingmodes interferometryobservingmodeimpl.cleanup(interferometryobservingmodeimpl.java:162 sun.reflect nativemethodaccessorimpl.invoke0(native method sun.reflect nativemethodaccessorimpl.invoke(nativemethodaccessorimpl.java:39 sun.reflect delegatingmethodaccessorimpl.invoke(delegatingmethodaccessorimpl.java:25 java.lang.reflect method.invoke(method.java:597 alma.acs.monitoring dynamicinterceptor.invoke(dynamicinterceptor.java:114 proxy3.cleanup(unknown source alma control interferometryobservingmodepoatie.cleanup(interferometryobservingmodepoatie.java:144 alma control._interferometryobservingmodestub.cleanup(_interferometryobservingmodestub.java:982 alma control observingmodes observingmodebaseimpl.shutdownobservingmode(observingmodebaseimpl.java:393 alma control array arraystatebase.deactivateoffshoots(arraystatebase.java:858 alma control array arraystatebase.endexecution(arraystatebase.java:780 alma control array manualarrayoperationalstate.endexecution(manualarrayoperationalstate.java:135 alma control array manualarrayimpl2.endexecution(manualarrayimpl2.java:504 sun.reflect nativemethodaccessorimpl.invoke0(native method sun.reflect nativemethodaccessorimpl.invoke(nativemethodaccessorimpl.java:39 sun.reflect delegatingmethodaccessorimpl.invoke(delegatingmethodaccessorimpl.java:25 java.lang.reflect method.invoke(method.java:597 alma.acs.monitoring dynamicinterceptor.invoke(dynamicinterceptor.java:114 proxy1.endexecution(unknown source alma control manualarraypoatie.endexecution(manualarraypoatie.java:94 alma control manualarraypoa._invoke(manualarraypoa.java:197 org.jacorb.poa requestprocessor.invokeoperation(requestprocessor.java:310 org.jacorb.poa requestprocessor.process(requestprocessor.java:604 org.jacorb.poa requestprocessor.run(requestprocessor.java:759 10t19:06:32.180 info control array003 interferometry observe mode shut noformat relevant corr log code xml error timestamp="2014 10t18:49:35.760 sourceobject="cdp_master_thread_0 file="arraythread.cpp line="3090 routine= host="cob cdpm b process="corr cdpmaster cppcontainer context= thread="cdp_master_thread_0 logid= uri= stackid= stacklevel="0"><![cdata[data not arrive time to=1368590 acs])]]></error info timestamp="2014 10t18:49:35.771 sourceobject="archive acc javacontainer file="alma.acs.profiling.orb acsorbprofilerimplbase line="303 routine="logstatus host="gas03 process="archive acc javacontainer context= thread="thread-77 logid="306 uri= stackid=""><![cdata[orb status connectionthreadsused=1 lose calls=0 requestqueuemaxusepercent=1 poa offshootpoa\').]]></info info timestamp="2014 10t18:49:35.778 sourceobject="archive tmcdb monitor_blobber10 file ...
#  'run -b -s --fail-- start end 07t23:57:20 08t00:02:39 execblock uid://a002 x785196 x9d alma build alma-10_4_0-b-2013 array array005 array corr m]/aca wednesday antenna cm02 fail follow error noformat 07t23:57:21.358 delaycal .py --load false --fluxlimit --subscanduration --wvrcount --looffset false --source --do180degphaseswitch false --polarization --width --scanseq false --numbasebands --autoonly false --subscanrepeats --threelooffset false --bblevel --ephem_file false --tfblo_shift_freq --allowquery false --band --minel --dozero false --imagesideband false --totalpower false --highband false --channelaverageduration --spavg --tsys false --reversebasebands false --mode tdm --dumpt --integrationduration --repeats asdm uid://a002 x785196 x9d 08t00:02:39.503 delaycal sort exception throw look log errortrace timestamp wed jan file=/groups science script r10.4_working line=679 routine=<module host crc-03 process=21756 thread mainthread type=10 code=3 shortdescrip unknown error severity error data errortrace timestamp wed jan file interferometryobservingmodeimpl.java line=149 routine initializecontrollers host gas01 process control acc javacontainer thread requestprocessor-1047 type=10410 code=5 shortdescrip error initialize observe mode severity error data message value failed cleanly activate observing mode array value array005 javaex.class value alma observingmodeexceptions.wrappers acsjobsmodeiniterrorex errortrace timestamp wed jan file observingmodecore.java line=275 routine addantmodecontroller host gas01 process control acc javacontainer thread requestprocessor-1047 type=10410 code=5 shortdescrip error initialize observe mode severity error data message value error get reference component call control cm02 antinterferometrycontroller array value array005 javaex.class value alma observingmodeexceptions.wrappers acsjobsmodeiniterrorex javaex.msg value= errortrace timestamp wed jan file containerservicesimpl.java line=691 routine getcollocatedcomponent host gas01 process control acc javacontainer thread requestprocessor-1047 type=6666 code=0 shortdescrip generic wrapper underlie exception severity error data javaex.class value alma javacontainererror.wrappers acsjcontainerservicesex contextinfo value unexpectedly fail retrieve component control cm02 antinterferometrycontroller create run collocate control cm02 javaex.msg value= errortrace timestamp wed jan file replyplaceholder.java line=140 routine getinputstream host gas01 process control acc javacontainer thread type=0 code=0 shortdescrip org.omg corba.timeout severity error data javaex.msg value client timeout reach javaex.class value org.omg corba.timeout 08t00:02:39.529 delaycal no observe mode 08t00:02:41.449 delaycal end execution uid uid://a002 x785196 x9d 08t00:02:41.449 delaycal trying export asdm 08t00:02:41.621 delaycal end execution asdm export 08t00:02:41.621 delaycal execblock complete 08t00:02:41.796 delaycal disconnect shutdown call client noformat reportsoftwaredeployment show follow issue dgck operational node ch 0x30l error unable find delay value delay track',
#  'dv12 show high trec tsys value observe band noformat uid://a002 xbaa732 x16f atmosphere cal results dv12 antenna(s baseband(s pol(s band scan antenna freq range baseband pol tsys trec sbgain dv12 bb_1 x dv12 bb_1 dv12 bb_3 x dv12 bb_3 noformat',
#  'observe antenna fail lock frequency ghz file attach',
#  'da58 show high trx band sky frequency ghz noformat atmospherereducedevent success execblockentityid uid://a002 xb3b3c9 x1084 scan finishedat 28t18:09:03.246000^m new result cal_atmosphere full_resolution_auto scans ^m validity start 28t18:07:46.669000 duration type temperature_scale^m ant da58 band alma_rb_03 freq 102.25ghz pres hpa temp k hum wh2o 1.96mm^m polar x tsys k trec k tatm k tau feff sbgain ^m polar tsys k trec k tatm k tau feff sbgain ^m ant da58 band alma_rb_03 freq 103.95ghz pres hpa temp k hum wh2o 1.96mm^m polar x tsys k trec k tatm k tau feff sbgain ^m polar tsys k trec k tatm k tau feff sbgain ^m ant da58 band alma_rb_03 freq 114.25ghz pres hpa temp k hum wh2o 1.96mm^m polar x tsys k trec k tatm k tau feff sbgain ^m polar tsys k trec k tatm k tau feff sbgain ^m ant da58 band alma_rb_03 freq 115.95ghz pres hpa temp k hum wh2o 1.96mm^m polar x tsys k trec k tatm k tau feff sbgain ^m polar tsys k trec k tatm k tau feff sbgain ^m noformat',
#  'prtspr report follow error correlator resource conflict datum cluster master node time happen get error like follow node noformat 20t06:50:47.222 corr cdpnode n11 cppcontainer gl collector fail unexpected hardware time stamp tid idx expect received=4443/126/2233826/2235874 20t06:50:44.902 corr cdpnode n11 cppcontainer gl collector fail unexpected hardware time stamp tid idx expect received=4426/109/2233681/2235729 noformat initially close prtspr duplicate ict-4575 difference problem report ict-4575 happen node not node associate dpi problem present even bl corr subsystem restart considering think problem relate hw',
#  'no result asdm not produce line auto correlation datum scan atm scan yellow triangle subscan not end end fine',
#  'try noformat mmex","2014 05t20:56:19 05t20:59:14","osf aos","2010.2.99006.csv","tfsd msb8.0.3","uid://a002 x95e355 --jira= -b -s -n -r -a array007","system","false","false noformat antenna not source servo failure cabinetemperature true utilitymodule power cycle not help not set axis autonomous remove array leave az el',
#  'timestamp 19t13:10:00 notice zenoss alarm daytime science observation',
#  'spectral response dv16 display amplitude dip ghz xx polarization see mous uid://a001 x133d x436 eb uid://a002 xd5371c x5a78 weblog',
#  'fe lock noformat uid://a002 xed4607 x7fb0 atmosphere cal results da58 antenna(s baseband(s pol(s band scan antenna freq range baseband pol tsys trec sbgain da58 bb_1 x da58 bb_1 da58 bb_2 x da58 bb_2 da58 bb_3 x da58 bb_3 da58 bb_4 x da58 bb_4 da58 bb_1 x da58 bb_1 da58 bb_2 x da58 bb_2 da58 bb_3 x da58 bb_3 da58 bb_4 x da58 bb_4 da58 bb_1 x da58 bb_1 da58 bb_2 x da58 bb_2 da58 bb_3 x da58 bb_3 da58 bb_4 x da58 bb_4 noformat auto generate ticket link exec webshiftlog?ebuid uid://a002 xed4607 x7fb0 link aqua webaqua?ebuid uid://a002 xed4607 x7fb0 link protrack protrack?schedblockuid uid://a001 x1465 x3bc7',
#  "run focus sbs version --success-- start end project code 0000.0.00187.csv pi nphillip schedblock focus band z execblock uid://a002 xae6c13 x290b sb uid uid://a002 x7b15a9 xb2 qa0 status band alma_rb_07 alma build 201508-cycle3-on b-2015 array array016 array corr m]/64-antenna friday try turn band time finally turn antenna not lock noformat frontend ant dv17 controller =/ state operational bands =/ available band alma_rb_03 alma_rb_04 alma_rb_05 alma_rb_06 available band alma_rb_07 alma_rb_08 alma_rb_09 alma_rb_10 powered band alma_rb_03 alma_rb_06 alma_rb_07 selected band =/ selected band alma_rb_07 lo1 frequency 349.999989[ghz sideband n locked no sis mixers |_sis pol usb mode open loop v -10633824471358863011665608641085440000.0000[mv]i |_sis pol lsb mode open loop v -10633824471358863011665608641085440000.0000[mv]i |_sis pol usb mode open loop v -10633824471358863011665608641085440000.0000[mv]i |_sis pol lsb mode open loop v -10633824471358863011665608641085440000.0000[mv]i lo pa drain voltage pol -10633823966279326983230456482242756608.0000[v]pol photomixer current -10633824471358863011665608641085440000.00[ma lpr =/ modulation voltage 0.00[v ifproc sideband power =/ ifproc sb power usb -42.323[dbm lsb -45.028[dbm ifproc sb power usb -60.000[dbm lsb -44.525[dbm cryostat =/ temperature |_4k stage 2.84[k 3.08[k 3.26[k |_4k stage 3.26[k 3.26[k |_15k stage 17.74[k 18.00[k 18.30[k |_15k stage 18.34[k |_110k stage 79.74[k 91.49[k 104.31[k |_110k stage 106.41[k pressure 1.2399e-07[mbar 281.59[mbar noformat try run fail noformat aos crc-07 almaop:~/dvcircularbuffers -b -p -a dv17 info data output path /groups engineer datum frontend locking/2016 xml test report file /groups engineer datum frontend locking/2016 locking_dv17_band7_2016 09.xml drivelprpower lprknee info lprpwr mw 01t07:36:13.652 cclsimpleclient initialize almaop@crc-07 init creating cvr ccl object step current state pll coarse tune pll bandwidth pll band lsb pll int pll ref tp v pll tp v pll corr volt v pll temperature c pll lock det v photomixer ma ma photomixer v v lpr port lpr current ma lpr power mw lpr max power mw lpr mod volt v sas pbs opt det dbm sas switch port cvr amplitude dbm cvr frequency ghz dv17 lock test band ghz step configuring band prn f1stlo ghz ffloog mhz fpr ghz fwca ghz fyig ghz coarse wca7 esn b4 a8 4f lpr esn d6 4e d4 a1 sas esn 9f fc step find lpr knee 01-jan-2016t07:36:14 lprknee lpr knee locate v step offset yig floog 01-jan-2016t07:36:16 offsetcoarsebyfloog coarse step set initial pll tp 01-jan-2016t07:36:16 setiftp lpr_u lpr_pwr photomixer if_tp traceback recent last file /groups engineer frontend script script line module locking.run file /alma acs-2014.6 acssw lib python site package fetoolbox line run iftp self.wcaopt.setiftp(pllif=-1.0 fcn_logger self._iftp_logger file /alma acs-2014.6 acssw lib python site package fetoolbox line setiftp self.lpr set_modulation_input_value(u file /alma acs-2014.6 acssw lib python site package ccl line set_modulation_input_value self._devices[key].set_modulation_input_value(world file /alma acs-2014.6 acssw lib python site package line set_modulation_input_value return omnipy.invoke(self set_modulation_input_value 0_control lprbase._d_set_modulation_input_value args controlexceptions camberrorex controlexceptions camberrorex(errortrace acserr errortrace(file='lprbase.cpp linenum=2431 routine='virtual void lprbase::set_modulation_input_value(corba::float host='dv17-abm process='control dv17 cppcontainer thread='orbtask timestamp=136709265764916830l sourceobject= errortype=10000l errorcode=0l severity error shortdescription='camb error data= previouserror=[acserr errortrace(file='lprimpl.cpp linenum=159 routine='virtual void lprimpl::setcntlmodulationinputvalue(float host='dv17-abm process='control dv17 cppcontainer thread='orbtask timestamp=136709265764905050l sourceobject= errortype=10000l errorcode=0l severity error shortdescription='camb error data=[acserr namevalue(name='detail value='the request ...
#  "device state lo2 noformat reportsoftwaredeployment -a dv04 19t08:59:44.534 python client initialize almaop@crc-01 disconnect shutdown call client 19t08:59:44.910 cclsimpleclient initialize almaop@crc-01 init creating antenna ccl object antenna dv04 antenna dv04 antenna status degraded pad a004 bl cai map lkm module cambservertpmc901.lkm receiver cabin temp devices acd operational node ch 0x28l cmpr operational node ch 0x25l coldcart3 operational node ch 0x13l coldcart4 not configured coldcart5 not configured coldcart6 operational node ch 0x13l coldcart7 operational node ch 0x13l coldcart8 not configured coldcart9 start node ch 0x13l coldcart10 not configured cryostat operational node ch 0x13l dgck operational node ch 0x30l drxbbpr0 operational node ch 0x112l drxbbpr1 operational node ch 0x152l drxbbpr2 operational node ch 0x192l drxbbpr3 operational node ch 0x1d2l dtsrbbpr0 not configured dtsrbbpr1 not configured dtsrbbpr2 not configured dtsrbbpr3 not configured dtxbbpr0 operational node ch 0x50l dtxbbpr1 operational node ch 0x51l dtxbbpr2 operational node ch 0x52l dtxbbpr3 operational node ch 0x53l feps operational node ch 0x26l get_output_state=1 floog operational node ch 0x32l holodsp not configured holorx not configured ifproc0 operational node ch 0x29l ifproc1 operational node ch 0x2al ifswitch operational node ch 0x13l llc operational node ch 0x203l lo2bbpr0 operational node ch 0x40l lo2bbpr1 operational node ch 0x41l lo2bbpr2 stop node ch 0x42l error device fail respond request unique id lo2bbpr3 operational node ch 0x43l lorr operational node ch 0x22l lpr operational node ch 0x13l mount operational node ch 0x0l psa operational node ch 0x60l get_ps_shutdown false psd operational node ch 0x61l get_ps_shutdown false powerdist3 operational node ch 0x13l get_cartridge_enable=1 powerdist4 not configured powerdist5 not configured powerdist6 operational node ch 0x13l get_cartridge_enable=1 powerdist7 operational node ch 0x13l get_cartridge_enable=1 powerdist8 not configured powerdist9 operational node ch 0x13l get_cartridge_enable=0 powerdist10 not configured sas operational node ch 0x303l wca3 operational node ch 0x13l wca4 not configured wca5 not configured wca6 operational node ch 0x13l wca7 operational node ch 0x13l wca8 not configured wca9 start node ch 0x13l wca10 not configured wvr operational node ch 0x24l 19t08:59:57.994 cclsimpleclient initialize almaop@crc-01 disconnect shutdown call clien noformat noformat get_devices('dv04 available abm parameters:['dv13 dv12 da48 dv01 da47 da46 dv03 dv02 da45 dv09 dv08 dv05 dv04 dv07 dv06 pm01 pm04 da43 da44 da42 da57 cm08 cm09 cm04 cm05 cm07 cm12 cm11 da50 da51 cm10 da54 da55 dv21 dv20 dv23 dv22 dv25 dv24 da64 da63 da62 cm02 cm03 dv14 dv11 dv18 dv15 dv19 dv17 aostiming acadmc dmc dmc2 dmc3 dmc4 lmc lmc2 lmc3 abm dv04 currently available device channel node 0x22 lo reference receiver lorr channel node 0x29 processor ifproc channel node 0x2a processor ifproc channel node 0x30 digitizer clock dgck channel node 0x32 lo offset generator floog channel node 0x40 lo synthesizer lo2 channel node 0x41 lo synthesizer lo2 channel node 0x43 lo synthesizer lo2 channel node 0x50 dts transmitter module dtx channel node 0x51 dts transmitter module dtx channel node 0x52 dts transmitter module dtx channel node 0x53 dts transmitter module dtx channel node 0x60 power supply analog rack psa channel node 0x61 power supply digital rack psd channel node 0x24 water vapour radiometer wvr channel node 0x13 end monitor control channel node 0x26 frontend power supply channel node 0x28 calibration widgets acd channel node 0x25 compressor cmpr channel node 0x0 antenna control unit acu noformat",
#  'problem see band happen band noformat uid://a002 xef72bb x44 atmosphere cal results da58 antenna(s baseband(s pol(s band scan antenna freq range baseband pol tsys trec sbgain da58 bb_1 x da58 bb_1 da58 bb_2 x da58 bb_2 da58 bb_3 x da58 bb_3 da58 bb_4 x da58 bb_4 noformat auto generate ticket link exec webshiftlog?ebuid uid://a002 xef72bb x1cf link aqua webaqua?ebuid uid://a002 xef72bb x1cf link protrack protrack?schedblockuid uid://a001 x1591 x1',
#  'try run delaycal antenna cm01 cm02 scrip fail correlator calibration process error happen twice occurrence check status aca corr find error state',
#  'troubleshoot hvac system verify node not respond necessary disable node software leave antenna operational programme activity check node locally',
#  'receiver cabin temperature deg psd go rodrigo guarda check issue not solve remotely antenna operation please check',
#  'sbex mapping dense shocked gas pc scales nuclear regions antennae galaxy version --running-- start end project code pi jueda schedblock ngc4038_c_b3_12 execblock uid://a002 x872bbc x1747 sb uid uid://a002 x7fb989 x24 qa0 status band alma_rb_03 alma build 201404-cycle2-on b-2014 array array019 array corr m]/64-antenna dv07 fail lock b3 run band lock noformat aos 9]>fe status frontend ant dv07 controller =/ state degraded bands =/ available band alma_rb_03 alma_rb_06 alma_rb_07 alma_rb_09 powered band alma_rb_03 alma_rb_06 alma_rb_07 selected band =/ selected band alma_rb_03 lo1 frequency 106.464387[ghz sideband usb locked no sis mixers |_sis pol usb mode closed loopv 10.2348[mv 44.7388[ua |_sis pol lsb mode closed loopv 10.3371[mv 42.2974[ua |_sis pol usb mode closed loopv 10.3088[mv 33.7524[ua |_sis pol lsb mode closed loopv 10.2287[mv 36.1328[ua lo pa drain voltage pol 0.6493[v pol 0.5992[v photomixer current 3.73[ma lpr =/ modulation voltage 2.14[v ifproc sideband power =/ ifproc sb power usb -30.202[dbm lsb -29.283[dbm ifproc sb power usb -30.144[dbm lsb -30.477[dbm cryostat =/ temperature |_4k stage 3.01[k 3.38[k 3.37[k |_4k stage 3.51[k 3.50[k |_15k stage 14.87[k 15.07[k 15.29[k |_15k stage 15.41[k |_110k stage 79.46[k 90.21[k 100.82[k |_110k stage 101.78[k pressure 1.0614e-08[mbar 997.94[mbar noformat',
#  'run unwinding secret recent thermal pulse sculpt wind sculptoris version --success-- start end project code pi maercker schedblock r_scl_a_07_12 execblock uid://a002 x97c221 x14fa sb uid uid://a002 x684eb5 x277 qa0 status band alma_rb_07 alma build 201404-cycle2-on b-2014 array array006 array corr m]/64-antenna da52 antenna show high temperature trec pol bb_1,2,4 band noformat uid://a002 x97c221 x14fa atmosphere cal results da52 antenna(s baseband(s pol(s band scan antenna freq range baseband pol tsys trec sbgain da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 noformat band noformat uid://a002 x97c221 x1a5a atmosphere cal results da52 antenna(s baseband(s pol(s band scan antenna freq range baseband pol tsys trec sbgain da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 da52 bb_1 x da52 bb_1 da52 bb_2 x da52 bb_2 da52 bb_3 x da52 bb_3 da52 bb_4 x da52 bb_4 noformat',
#  'morning notify aca correlator not recover reset system check status realize quadrant powon issue noformat ape1 coj cc-1 deherrer:~ -a status quadrant 15t13:47:43 aca corr dfp cip status ok aca corr initialization status normal mode aca corr powon diag status error quadrant 15t13:47:43 aca corr dfp cip status ok aca corr initialization status normal mode aca corr powon diag status ok quadrant 15t13:47:43 aca corr dfp cip status ok aca corr initialization status normal mode aca corr powon diag status ok quadrant 15t13:47:43 aca corr dfp cip status ok aca corr initialization status normal mode aca corr powon diag status ok noformat',
#  'aos fire system cheetah controller not functional controller not reset',
#  "run titan spectral scan version --fail-- start end project code 0000.0.00266.csv pi dgarcia schedblock titan_b_07_te execblock uid://a002 x977bfb x1bfc sb uid uid://a002 x973cfe x7 qa0 status band alma_rb_07 alma build alma-10_6_0-b-2014 array array025 array corr m]/64-antenna monday error jlog noformat 22t12:32:52.429 error corr ccc cppcontainer gl invalid array type=20000 code=10 22t12:32:47.634 info control array028 tuning bb_1 360.000ghz band 22t12:32:46.857 info control cm07 frontend receiver band select 22t12:32:46.682 warning control da59 floog counted incorrect numb 125mhz clock cycle lead phase jump please check floog necessary switch invert clock set_clock_inversion command reset latch reset_fts_status command 22t12:32:46.615 info control array025 interferometry observe mode shut 22t12:32:46.583 critical none error script execution acserr errortrace(file='/alma acs-12.2 acssw bin linenum=138 routine='<module host='gas01 process='19744 thread='mainthread timestamp=136385443665768340l sourceobject= errortype=10100l errorcode=5l severity error shortdescription='general scriptexecutor runtime error data= previouserror=[acserr errortrace(file='/alma acs-12.2 acssw bin linenum=132 routine='<module host='gas01 process='19744 thread='mainthread timestamp=136385443665705472l sourceobject= errortype=7l errorcode=0l severity error shortdescription='a python exception data=[acserr namevalue(name='real description value='none acserr namevalue(name='traceback value='traceback recent last):\\n file /alma acs-12.2 acssw bin line module>\\n result executor.runsource(srccode)\\n file /alma acs-12.2 acssw lib python site package scriptexec line runsource\\n exec source self._globals self._locals\\n file string line module>\\n file /alma acs current acssw intlist srr106_acceptance lib python site package observation line preparetargets\\n targetinfo targetinfo cal true caltype 0)\\n file /alma acs current acssw intlist srr106_acceptance lib python site package observation line expandsourcequeries\\n raise sbexecutionerror msg\\nsbexecutionerror no query result phase calibration not pass selection criterium exiting\\n previouserror= 22t12:32:46.581 critical none setexecerror error script execution acserr errortrace(file='/alma acs-12.2 acssw bin linenum=138 routine='<module host='gas01 process='19744 thread='mainthread timestamp=136385443665768340l sourceobject= errortype=10100l errorcode=5l severity error shortdescription='general scriptexecutor runtime error data= previouserror=[acserr errortrace(file='/alma acs-12.2 acssw bin linenum=132 routine='<module host='gas01 process='19744 thread='mainthread timestamp=136385443665705472l sourceobject= errortype=7l errorcode=0l severity error shortdescription='a python exception data=[acserr namevalue(name='real description value='none acserr namevalue(name='traceback value='traceback recent last):\\n file /alma acs-12.2 acssw bin line module>\\n result executor.runsource(srccode)\\n file /alma acs-12.2 acssw lib python site package scriptexec line runsource\\n exec source self._globals self._locals\\n file string line module>\\n file /alma acs current acssw intlist srr106_acceptance lib python site package observation line preparetargets\\n targetinfo targetinfo cal true caltype 0)\\n file /alma acs current acssw intlist srr106_acceptance lib python site package observation line expandsourcequeries\\n raise sbexecutionerror msg\\nsbexecutionerror no query result phase calibration not pass selection criterium exiting\\n previouserror= 22t12:32:46.511 error ssr array025-bl standardinterferometry expandsourcequeries no query result phase calibration not pass selection criterium exit noformat error python container noformat 22t12:32:58.438 warning control acc javacontainer unexpected exception throw functional method control array025 alma control arraymountcontroller#getpointingdata java.util concurrentmodificationexception java.util treemap$privateentryiterator.nextentry(treemap.java:1100 java. ...
#  'trying tiltmeter measurement find dv16_mmc.png|width=600',
#  'whie run noformat alma mm spectroscopic survey hubble ultra deep field version --running-- start end project code pi maravena schedblock udf1_d_06_te execblock uid://a002 x9896b4 x447 sb uid uid://a001 x13f x4b qa0 status band alma_rb_06 alma build 201404-cycle2-on b-2014 array array006 array corr m]/64-antenna noformat telcal start flag datum dv11 noformat 02t23:34:38.071 telcal flag antenna dv11 ambient load temperature incorrect 02t23:34:38.072 telcal flag antenna dv11 hot load temperature incorrect 02t23:44:32.521 telcal flag antenna dv11 ambient load temperature incorrect 02t23:44:32.522 telcal flag antenna dv11 hot load temperature incorrect 02t23:51:38.368 telcal flag antenna dv11 ambient load temperature incorrect 02t23:51:38.369 telcal flag antenna dv11 hot load temperature incorrect 03t00:10:29.479 telcal flag antenna dv11 ambient load temperature incorrect 03t00:10:29.479 telcal flag antenna dv11 hot load temperature incorrect 03t00:28:19.870 telcal flag antenna dv11 hot load temperature incorrect 03t00:46:10.988 telcal flag antenna dv11 hot load temperature incorrect 03t01:39:27.764 telcal flag antenna dv11 ambient load temperature incorrect 03t01:39:27.764 telcal flag antenna dv11 hot load temperature incorrect 03t01:44:52.897 telcal flag antenna dv11 ambient load temperature incorrect 03t01:44:52.897 telcal flag antenna dv11 hot load temperature incorrect noformat issue start utc aprox run uid://a002 x9896b4 xdc reset acd problem remain noformat os crc-01 almaop:~ -a dv11 -s dv11 device state change operational successfully dv11 sending acd reset ccl cmd dv11 acd reset device dv11 sending acd reset_device ccl cmd dv11 acd hardware reset dv11 sending acd init ccl cmd dv11 waiting dv11 acd init device dv11 acd cartridge set park0 dv11 acd device initialization antennas acd funtions state dv11 acd state acd cartridge position park0 acd load position ambient acd rerence temp c acd ambient load temps c acd hot load temps 85(c reach end script 03t00:57:54.409 python client initialize almaop@crc-01 disconnect shutdown call client noformat antenna container noformat acd movement time set acdcsv,25124780,2,6 02t23:51:35.196 ambserver loggerthread monitor timeout receive channel node 0x28 rca 0x1 02t23:51:35.196 control da58 cppcontainer gl virtual void ambdeviceimpl::monitorenc(acs::time const ambsystem::ambrelativeaddr ambdatalength_t ambdatamem_t camb error ype=10000 code=0 detail="the monitor request return error amb status channel node numb 0x28 rca 0x1 02t23:51:35.198 control da58 frontend acd void acdimpl::updatethreadaction caught exception try determine acd need raise low flag ignoring 02t23:51:35.203 ambserver loggerthread monitor timeout receive channel node 0x28 rca 0x1 02t23:51:35.203 control da58 cppcontainer gl virtual void ambdeviceimpl::monitorenc(acs::time const ambsystem::ambrelativeaddr ambdatalength_t ambdatamem_t camb error ype=10000 code=0 detail="the monitor request return error amb status channel node numb 0x28 rca 0x1 02t23:51:35.233 ambserver loggerthread monitor timeout receive channel node 0x28 rca 0x1 02t23:51:35.233 control da58 cppcontainer gl virtual void ambdeviceimpl::monitorenc(acs::time const ambsystem::ambrelativeaddr ambdatalength_t ambdatamem_t camb error ype=10000 code=0 detail="the monitor request return error amb status channel node numb 0x28 rca 0x1 02t23:51:35.250 ambserver loggerthread monitor timeout receive channel node 0x28 rca 0x1 02t23:51:35.250 control da58 cppcontainer gl virtual void ambdeviceimpl::monitorenc(acs::time const ambsystem::ambrelativeaddr ambdatalength_t ambdatamem_t camb error ype=10000 code=0 detail="the monitor request return error amb status channel node numb 0x28 rca 0x1 02t23:51:35.254 ambserver loggerthread monitor timeout receive channel node 0x28 rca 0x7 02t23:51:35.254 control da58 cppcontainer gl virtual void ambdeviceimpl::monitorenc(acs::time const ambsystem::ambrelativeaddr ambdatalength_t ambdatamem_t camb error ype=10000 code=0 detail="the ...
#  'weather value weather station tb2 exclusively telcal control system early science ict-5883 however notice pressure reading much noisy tb2 weather station particularly daytime peak peak noise high mb correspond ambient pressure delta path order mm excess noise appear correlate high wind daytime wind baffle station different station improve pressure reading stable plot below show datum past week extract tmcdb minute interval scale height sea level formula ict-272 t=0c yellow shade region correspond daytime hour pressure_2015 11_2015 16.png|thumbnail',
#  'auto generate ticket link exec webshiftlog?ebuid uid://a002 xec4582 x2 link aqua webaqua?ebuid uid://a002 xec4582 x2 link protrack protrack?schedblockuid uid://a001 x12a3 x71b xterminal psa stop error noformat ape2 crc-23 almaop:/mnt gn data2 user almaop reportsoftwaredeployment -a dv02 20t02:40:21.040 python client initialize almaop@crc-23 disconnect disconnect call client 20t02:40:21.060 cclsimpleclient initialize almaop@crc-23 init creating antenna ccl object antenna dv02 antenna dv02 antenna status degraded pad a062 bl cai map not define lkm module cambservertpmc901-tempe.lkm receiver cabin temp devices acd operational node ch 0x28l error set value heater not inside range allow cmpr operational node ch 0x25l coldcart1 not configured coldcart3 operational node ch 0x13l coldcart4 start node ch 0x13l coldcart5 start node ch 0x13l coldcart6 operational node ch 0x13l coldcart7 operational node ch 0x13l coldcart8 start node ch 0x13l coldcart9 start node ch 0x13l coldcart10 start node ch 0x13l cryostat operational node ch 0x13l dgck operational node ch 0x30l drxbbpr0 operational node ch 0x114l drxbbpr1 operational node ch 0x154l drxbbpr2 operational node ch 0x194l drxbbpr3 operational node ch 0x1d4l dtsrbbpr0 not configured dtsrbbpr1 not configured dtsrbbpr2 not configured dtsrbbpr3 not configured dtxbbpr0 operational node ch 0x50l dtxbbpr1 operational node ch 0x51l dtxbbpr2 operational node ch 0x52l dtxbbpr3 operational node ch 0x53l feps operational node ch 0x26l get_output_state=1 fetim operational node ch 0x13l floog operational node ch 0x32l ifproc0 operational node ch 0x29l ifproc1 operational node ch 0x2al ifswitch operational node ch 0x13l llc operational node ch 0x201l lo2bbpr0 operational node ch 0x40l lo2bbpr1 operational node ch 0x41l lo2bbpr2 operational node ch 0x42l lo2bbpr3 operational node ch 0x43l lorr operational node ch 0x22l lpr operational node ch 0x13l mount operational node ch 0x0l psa stop node ch 0x60l error control dv02 psa fail respond request unique id psd operational node ch 0x61l get_ps_shutdown false powerdist1 not configured powerdist3 operational node ch 0x13l get_cartridge_enable=1 powerdist4 operational node ch 0x13l get_cartridge_enable=0 powerdist5 operational node ch 0x13l get_cartridge_enable=0 powerdist6 operational node ch 0x13l get_cartridge_enable=1 powerdist7 operational node ch 0x13l get_cartridge_enable=1 powerdist8 operational node ch 0x13l get_cartridge_enable=0 powerdist9 operational node ch 0x13l get_cartridge_enable=0 powerdist10 operational node ch 0x13l get_cartridge_enable=0 sas operational node ch 0x301l wca1 not configured wca3 operational node ch 0x13l wca4 start node ch 0x13l wca5 start node ch 0x13l wca6 operational node ch 0x13l wca7 operational node ch 0x13l wca8 start node ch 0x13l wca9 start node ch 0x13l wca10 start node ch 0x13l wvr operational node ch 0x24l 20t02:40:23.842 cclsimpleclient initialize almaop@crc-23 disconnect disconnect call client 20t02:40:23.843 python client initialize almaop@crc-23 disconnect disconnect call client noformat',
#  'observation lose fringe antenna drxreset solve problem minute',
#  'antenna fine problem causes separate let start diagnosis noformat atmospherereducedevent success execblockentityid uid://a002 x868782 x6ab scan finishedat 13t04:51:27.951000 new result cal_atmosphere full_resolution_auto scans validity start 13t04:50:40.367000 duration type temperature_scale ant da59 band alma_rb_03 freq 96.99ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain ant da59 band alma_rb_03 freq 98.93ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain ant da59 band alma_rb_03 freq 108.99ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain ant da59 band alma_rb_03 freq 110.99ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain ant dv14 band alma_rb_03 freq 96.99ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain ant dv14 band alma_rb_03 freq 98.93ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain ant dv14 band alma_rb_03 freq 108.99ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain ant dv14 band alma_rb_03 freq 110.99ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain ant dv16 band alma_rb_03 freq 96.99ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain ant dv16 band alma_rb_03 freq 98.93ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain ant dv16 band alma_rb_03 freq 108.99ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain ant dv16 band alma_rb_03 freq 110.99ghz pres hpa temp k hum wh2o mm polar x tsys k trec k tatm k tau feff sbgain polar tsys k trec k tatm k tau feff sbgain noformat array noformat got array control array009 correlator type bl num antennas antennas cm01 cm02 cm03 cm04 cm05 cm06 cm09 cm11 cm12 da42 da44 da46 da50 da55 da59 da61 da62 da64 da65 dv07 dv09 dv10 dv11 dv13 dv14 dv15 dv16 dv19 dv22 dv23 dv25 pm02 pm04 photonic reference photonicreference1 exec block uid://a002 x868782 x6ab noformat',
#  'da45 degraded dgck stop degraded device fail respond request unique id dtxbbpr0 stop degraded device fail respond request unique id dtxbbpr1 stop degraded device fail respond request unique id dtxbbpr2 stop degraded device fail respond request unique id dtxbbpr3 stop degraded device fail respond request unique id',
#  'observe interactive array sb band dv12 fail lock frequencies bb_1 90.995ghz bb_2 92.932ghz bb_3 102.995ghz bb_4 104.995ghz band message jlog point safe threshold reach photopower detector antenna lock fine frequency',
#  'run nuclear continuum spectra nearby low luminosity agns version --running-- start end project code pi doi schedblock multi source b7b execblock uid://a002 x828760 x454 sb uid uid://a002 x5a9a13 xe1 qa0 status band alma_rb_07 alma build alma-9_1_r5-online b-2014 array array014 array corr m]/64-antenna quicklook show wrong system temperature value antenna dv09 bad point result',
#  'dynamic pressure helium circuit drop mpa',
#  "observe noformat comparing morphology kinematics warm co warm molecular hydrogen star forming galaxies version --fail-- start end project code pi nrangwala schedblock ngc_253_a_09_7 execblock uid://a002 xa9eaf0 xaa4 sb uid uid://a001 x2cf x10 qa0 status band alma_rb_09 alma build 201508-cycle3-on b-2015 array array010 array corr m]/aca tuesday noformat sb fail complain spectral window validation bbprs noformat 08t07:16:28.542 ssr array010-aca standardinterferometry array010-aca atmcaltarget exception throw obsmode.getcalibrationids consider fatal 08t07:16:28.543 ssr array010-aca standardinterferometry array010-aca atmcaltarget controlexceptions fatalex(errortrace acserr errortrace(file='interferometrycontrollerimpl.java linenum=500 routine='loadconfigurations private host='gas01 process= thread='requestprocessor-63223 timestamp=136609893885410000l sourceobject='control array010 errortype=10000l errorcode=16l severity error shortdescription='an unrecoverable error oc cure data=[acserr namevalue(name='usererrormessage value='cannot load configuration correlator acserr namevalue(name='javaex.class value='alma controlexceptions.wrappers acsjfatalex previouserror=[acserr .errortrace(file='acacorr_observationcontrolimpl.cpp linenum=3887 routine='acacorr_observationcontrolimpl::createcorrconfigsets host='coj cc-1 process='acacorr observation_control cppcontainer thread='orbtask timestamp sourceobject='control array010 errortype=20000l errorcode=0l severity error shortdescription='invalid configuration data=[acserr namevalue(name='cause value='configuration fail validation pectral window[1 bb_1 low bind spectral window great equal 31.25mhz 0mhz spectral window[1 bb_1 upper bind spectral window little equal 1,968.75mhz bu 2,000mhz spectral window[1 bb_2 low bind spectral window great equal 31.25mhz 0mhz spectral window[1 bb_2 upper bind spectral window little equal 1,968.75mhz 2,000mhz spectral window[1 bb_3 low bind spectral window great equal 31.25mhz 0mhz spectral window[1 bb_3 upper bind spectral window little han equal 1,968.75mhz 2,000mhz acserr namevalue(name='javaex.class value='alma.acs.exceptions defaultacsjexception acserr namevalue(name='javaex.msg value= previouserror= 08t07:16:28.543 ssr array010-aca standardinterferometry array010-aca atmcaltarget pretty trace errortrace timestamp tue sep file interferometrycontrollerimpl.java line=500 routine loadconfigurationsprivate host gas01 process= thread requestprocessor-63223 type=10000 code=16 shortdescrip unrecoverable error occur severity error data usererrormessage value cannot load configuration correlator javaex.class value alma controlexceptions.wrappers acsjfatalex errortrace timestamp tue sep file acacorr_observationcontrolimpl.cpp line=3887 routine acacorr_observationcontrolimpl::createcorrconfigsets host coj cc-1 process acacorr observation_control cppcontainer thread orbtask type=20000 code=0 shortdescrip invalid configuration severity error data cause value configuration fail validation spectral window[1 bb_1 low bind spectral window great equal 31.25mhz 0mhz spectral window[1 bb_1 bind spectral window little equal 1,968.75mhz 2,000mhz spectral window[1 bb_2 low bind spectral window great equal 31.25mhz 0mhz spectral window bb_2 upper bind spectral window little equal 1,968.75mhz 2,000mhz spectral window[1 bb_3 low bind spectral window great equal 31.25mhz 0mhz spectral window[1 bb_3 upper bind spectral window little equal 1,968.75mhz 2,000mhz javaex.class value alma.acs.exceptions defaultacsjexception javaex.msg value= 08t07:16:28.548 ssr array010-aca standardinterferometry array010-aca standardinterferometry exception catch controlexceptions fatalex(errortrace acserr errortrace(file='interferometrycontrollerimpl.java linenum=500 routine='loadconfigurationsprivate host='gas01 process= thread='requestprocessor-63223 timestamp=136609893885410000l sourceobject='control array010 errortype=10000l errorcode=16l severity error shortdescription='a n unrecoverable error o ...
#  'auto generate ticket link exec webshiftlog?ebuid uid://a002 xfda0c7 x2 link aqua webaqua?ebuid uid://a002 xfda0c7 x2 link protrack protrack?schedblockuid uid://a001 x12a3 x71b noformat summary not supply parameter system state estimate long tune cannot execute monitor control request device inactive timestamp details error trace code type file localoscillatorimpl.java host gas01 line number process control acc javacontainer routine timetotune short description illegal parameter error source object control array1-blc thread requestprocessor-1167 additional data usererrormessage value not supply parameter system state estimate long tune javaex.class value alma controlexceptions.wrappers acsjillegalparametererrorex error trace code type file frontendexternal.cpp host dv18-abm line number process control dv18 cppcontainer routine virtual acs::timeintervalseq frontendimpl::timetotune(const control::frontend::tuningtimeinfoseq short description inactive source object control array1-blc thread orbtask additional data javaex.class value alma.acs.exceptions defaultacsjexception javaex.msg value error trace code type file acdbase.cpp host dv18-abm line number process control dv18 cppcontainer routine virtual uint8_t acdbase::getstatusload(acs::time short description inactive source object control array1-blc thread orbtask additional data usererrormessage value not execute monitor control request device inactive javaex.class value alma.acs.exceptions defaultacsjexception javaex.msg value noformat',
# ...
#  'run -b -o -z -a array012 --fail-- start end execblock uid://a002 x76d47f xbfe alma build alma-10_2_0-b-2013 array array012 array corr m]/64-antenna ut tsawada dv09 total power processor hardware issue monday antenna dv09 go error not specify total power processor consume datum antenna dv09',
#  "sbex fdm polarization leakage selected frequencies version --fail-- start end project code 0000.0.00226.csv pi knakanishi schedblock b6 sio co execblock uid://a002 x89b9cb x168 sb uid uid://a002 x89b9c4 xc qa0 status band alma_rb_06 alma build alma-10_6_0-b-2014 array array006 array corr m]/64-antenna according alarm panel happen ut03:35 without apparent reason noformat aos crc-01 almaop:~ -a da43 -s antenna devices state error da43 degraded lorr stop floog stop acd operational degraded set value heater not inside range allow ifproc0 stop ifproc1 stop lo2bbpr0 stop lo2bbpr1 stop lo2bbpr2 stop lo2bbpr3 stop noformat noformat aos 32]>psa status psa ant da43 general =/ global warning err modules ok err amb temp 26.94[c power supply status |_enabled current state shutdown cmd no |_temp monitor temp okay shutdown temp |_limits current okay voltage okay |_status ac okay dc err |_fan status okay warning okay shutdown error message normal no shutdown code record reported lambda error no lambda error reported reported low internal comm error err_rx_0 timed waiting response reported mid internal comm error no mid level internal comm error reported/ alive counter psa specific =/ mid voltage mid current mid max voltage see mid min voltage see mid max current see mid voltage mid current mid max voltage see mid min voltage see mid max current see mid voltage mid current mid max voltage see mid min voltage see mid max current see mid voltage mid current mid max voltage see mid min voltage see mid max current see mid voltage mid current mid max voltage see mid min voltage see mid max current see state last shutdown =/ mid shutdown voltage mid shutdown current mid shutdown voltage mid shutdown current mid shutdown voltage mid shutdown current mid shutdown voltage mid shutdown current mid shutdown voltage mid shutdown current temp shutdown noformat note not high temperature log jlog noformat 20t03:24:42.450 error control da43 cppcontainer gl problem hardware type=10006 code=5 20t03:24:42.447 error control da43 cppcontainer gl inactive type=10000 code=14 20t03:24:41.999 info control da43 frontend receiver band select noformat javacontainer noformat 20t03:24:43.184 info control array006 saving current attenuator setting atm_co calibration setup_1 java.lang runtimeexception unexpected exception idl alma controlexceptions inacterrorex:1.0 alma control._antlocontrollerstub.getattenuatorvalues(_antlocontrollerstub.java:1803 alma control observingmodes localoscillatorimpl.optimizesignallevels(localoscillatorimpl.java:592 alma control observingmodes localoscilatorthread.run(localoscilatorthread.java:143 20t03:24:43.203 error control array006 error invoke observe mode function type=10410 code=0 20t03:24:43.202 error control array006 java.lang runtimeexception type=9 code=-1 unexpected exception idl alma controlexceptions inacterrorex:1.0 20t03:24:43.204 warning control array006 aborting subsequence 20t03:24:46.260 info control acc javacontainer orb status connectionthreadsused=15 lose calls=0 requestqueuemaxusepercent=28 poa componentpoa_cont rol array006 noformat pythoncontainer noformat 20t03:20:39.576 cclsimpleclient initialize almaproc@gas01 waiting second 20t03:24:49.338 cclsimpleclient initialize almaproc@gas01 array006-bl scanlist traceback recent last file /alma acs current acssw intlist ssr lib python site package observation line execute obsmode.doscansequence(scansequence file /alma acs-12.2 acssw lib python site package ccl line doscansequence cb.waitforcompletion(timetowait file /alma acs-12.2 acssw lib python site package controlcommoncallbacks line waitforcompletion raise ex asynchronousfailureeximpl controlcommonexceptionsimpl asynchronousfailureeximpl(errortrace acserr errortrace(file='observingmodeerroracsjcompletion.java linenum=41 routine='<init host='gas01 process='control acc javacontainer thread='thread-23231703 timestamp=136277976395750000l sourceobject='control array006 error type=10410l errorcode=0l severity error shortdescri ...
#  "trying observe antenna realize coudln't signal checking frontend see cryostat high temperature normal noformat frontend ant cm08 controller =/ state degraded bands =/ available band alma_rb_03 alma_rb_06 alma_rb_07 alma_rb_09 powered band alma_rb_03 alma_rb_06 alma_rb_07 selected band =/ selected band alma_rb_06 lo1 frequency 223.006654[ghz sideband usb locked yes sis mixers |_sis pol usb mode closed loopv -8.5426[mv -142.4561[ua |_sis pol lsb mode closed loopv 8.5304[mv 119.6899[ua |_sis pol usb mode closed loopv -8.4999[mv -114.2578[ua |_sis pol lsb mode closed loopv 8.5220[mv 111.2671[ua lo pa drain voltage pol 2.7429[v pol 3.0731[v photomixer current 0.53[ma lpr =/ modulation voltage 1.72[v ifproc sideband power =/ ifproc sb power usb -29.714[dbm lsb -29.598[dbm ifproc sb power usb -30.052[dbm lsb -30.278[dbm cryostat =/ temperature |_4k stage 5.61[k 6.53[k 6.46[k |_4k stage 7.16[k 7.17[k |_15k stage 32.43[k 33.59[k 34.82[k |_15k stage 35.71[k |_110k stage 90.71[k 103.21[k 115.48[k |_110k stage 117.19[k pressure 2.3210e-04[mbar 997.94[mbar noformat",
#  'normal procedure handover science find antenna shutter not open noformat -b -s noformat',
#  'middle observation see very strange pattern autocorrelation cm1 cm2 auto generate ticket link exec webshiftlog?ebuid uid://a002 xdf9c1c xbda link aqua webaqua?ebuid uid://a002 xdf9c1c xbda link protrack protrack?schedblockuid uid://a001 x133d xa80',
#  'auto generate ticket link exec webshiftlog?ebuid uid://a002 xf7519f x282a link aqua webaqua?ebuid uid://a002 xf7519f x282a link protrack protrack?schedblockuid uid://a001 x1590 x25ec cryo temp noformat cryostat ant da64 status =/ supply current -3.0[a pumping substate unknown backing pump note follow value available back pump turbo pump turbo pump speed unknown gate valve unknown solenoid valve unknown temperature =/ k cryocooler 3.96[k k plate near link1 4.31[k k plate near link2 4.29[k k plate far side1 4.53[k k plate far side2 4.53[k k cryocooler 31.82[k k plate near link 32.31[k k plate far 32.78[k k shield top 32.65[k k cryocooler 106.89[k k plate near link 120.19[k k plate far 131.92[k k shield top 134.32[k vacuum gauge =/ vacuum gauge sensor 8.6442e-06[pascal 8.6442e-08[mbar sensor 612.76[pascal 6.13[mbar noformat',
#  "suddenly dmc2 container go get request component not activate request time drxbbpr1 antenna noformat alarm manager control dmc2 cppcontainer,1 active priority send cause null action null description container aos crc-01 almaop:~ reportsoftwaredeployment -a cm05[k[k[k[kdv04 20t09:01:51.863 python client initialize almaop@crc-01 disconnect disconnect call client 20t09:01:52.254 cclsimpleclient initialize almaop@crc-01 init creating antenna ccl object antenna dv04 antenna dv04 antenna status degraded pad a078 bl cai map lkm module cambservertpmc901.lkm receiver cabin temp devices 0macd operational node ch 0x28l error set value heater not inside range allowed[0 0mcmpr operational node ch 0x25l 0mcoldcart3 operational node ch 0x13l 33mcoldcart4 start node ch 0x13l 34mcoldcart5 not configured[0 33mcoldcart6 stop node ch 0x13l 0mcoldcart7 operational node ch 0x13l 0mcoldcart8 operational node ch 0x13l 33mcoldcart9 stop node ch 0x13l 33mcoldcart10 stop node ch 0x13l 0mcryostat operational node ch 0x13l 0mdgck operational node ch 0x30l 0mdrxbbpr0 operational node ch 0x112l problem try instantiate drxbbpr1 macierrtype componentnotalreadyactivatedex(errortrace acserr errortrace(file='managerproxyimpl.java linenum=605 routine='get_component_non_sticky host='gas05 process= thread='requestprocessor-11321 timestamp=136304965174200000l sourceobject= errortype=25l errorcode=2l severity error shortdescription='the request component not activate request time data=[acserr namevalue(name='javaex.class value='alma.macierrtype.wrappers acsjcomponentnotalreadyactivatedex previouserror= 31mdrxbbpr1 n node ch n n 41msimulated[0 error macierrtype componentnotalreadyactivatedex(errortrace acserr errortrace(file='managerproxyimpl.java linenum=605 routine='get_component_non_sticky host='gas05 process= thread='requestprocessor-11321 timestamp=136304965174200000l sourceobject= errortype=25l errorcode=2l severity error shortdescription='the request component not activate request time data=[acserr namevalue(name='javaex.class value='alma.macierrtype.wrappers acsjcomponentnotalreadyactivatedex previouserror=[]))[0 0mdrxbbpr2 operational node ch 0x192l 0mdrxbbpr3 operational node ch 0x1d2l 34mdtsrbbpr0 not configured[0 34mdtsrbbpr1 not configured[0 34mdtsrbbpr2 not configured[0 34mdtsrbbpr3 not configured[0 0mdtxbbpr0 operational node ch 0x50l 0mdtxbbpr1 operational node ch 0x51l 0mdtxbbpr2 operational node ch 0x52l 0mdtxbbpr3 operational node ch 0x53l 0mfeps operational node ch 0x26l get_output_state=1 0mfloog operational node ch 0x32l 34mholodsp not configured[0 34mholorx not configured[0 0mifproc0 operational node ch 0x29l 0mifproc1 operational node ch 0x2al 0mifswitch operational node ch 0x13l 0mllc operational node ch 0x203l 0mlo2bbpr0 operational node ch 0x40l 0mlo2bbpr1 operational node ch 0x41l 0mlo2bbpr2 operational node ch 0x42l 0mlo2bbpr3 operational node ch 0x43l 0mlorr operational node ch 0x22l 0mlpr operational node ch 0x13l 0mmount operational node ch 0x0l 0mpsa operational node ch 0x60l get_ps_shutdown false 0mpsd operational node ch 0x61l get_ps_shutdown false 0mpowerdist3 operational node ch 0x13l get_cartridge_enable=1 0mpowerdist4 operational node ch 0x13l get_cartridge_enable=0 34mpowerdist5 not configured[0 0mpowerdist6 operational node ch 0x13l get_cartridge_enable=0 0mpowerdist7 operational node ch 0x13l get_cartridge_enable=1 0mpowerdist8 operational node ch 0x13l get_cartridge_enable=1 0mpowerdist9 operational node ch 0x13l get_cartridge_enable=0 0mpowerdist10 operational node ch 0x13l get_cartridge_enable=0 0msas operational node ch 0x303l 0mwca3 operational node ch 0x13l 33mwca4 start node ch 0x13l 34mwca5 not configured[0 33mwca6 stop node ch 0x13l 0mwca7 operational node ch 0x13l 0mwca8 operational node ch 0x13l 33mwca9 stop node ch 0x13l 33mwca10 stop node ch 0x13l 0mwvr operational node ch 0x24l 20t09:02:09.473 cclsimpleclient initialize almaop@crc-01 disconnect disconnect call client 20t09:02:09.476 python client initialize alm ...
#  'pm04 not lock band lo1 frequency 806.218650[ghz ccl noformat ape2 3]>f frontend("pm04")ape2 4]>f status frontend ant pm04 controller =/ state degraded bands =/ available band alma_rb_03 alma_rb_04 alma_rb_05 alma_rb_06 available band alma_rb_07 alma_rb_08 alma_rb_09 alma_rb_10 powered band alma_rb_10 selected band =/ selected band alma_rb_10 lo1 frequency 806.218650[ghz sideband usb locked no sis mixers |_sis pol dsb mode closed loopv 1.8906[mv 40.1306[ua |_sis pol dsb mode closed loopv 1.9272[mv 38.7268[ua lo pa drain voltage pol 3.3778[v pol 3.1302[v photomixer current 2.28[ma lpr =/ modulation voltage 1.95[v ifproc sideband power =/ ifproc sb power usb -27.754[dbm lsb -44.255[dbm ifproc sb power usb -26.190[dbm lsb -42.304[dbm cryostat =/ temperature |_4k stage 2.95[k 3.20[k 3.19[k |_4k stage 3.42[k 3.42[k |_15k stage 17.17[k 17.53[k 17.76[k |_15k stage 17.97[k |_110k stage 79.55[k 93.78[k 106.30[k |_110k stage 109.86[k pressure 2.0760e-08[mbar 528.15[mbar noformat',
#  'antenna not lock b3,6,7',
#  'yesterday replace ifproc0 unit dv09 antenna prtsir-17167 retake ing verification show polo ambdip signal instabilities fix bands except b7 wca7 unit malfunction not want lock affect pend b7 ambdip tpstability measurement aiv-21879 ticket',
#  'noformat sunday jan utc author details sbex grid survey ot version --fail-- start end project code 0000.0.00287.csv pi nphillip schedblock grid survey b3 execblock uid://a002 xaebbcb x4bbe sb uid uid://a002 x9c637c x53 qa0 status band alma_rb_03 alma build 201508-cycle3-on b-2016 array array051 array corr unknown aca noformat noformat summary problem execute sub scan sequence contain sub scan problem complete sub scan general bulkdata error details error trace code type file subscansequenceexecutor.java host gas01 line number process control acc javacontainer routine run short description unrecoverable error occur source object control array051 thread thread-33978 additional data subscan value usererrormessage value problem execute sub scan sequence contain sub scan scan value javaex.class value alma controlexceptions.wrappers acsjfatalex error trace code type file totalpowerseqcbimpl.java host gas01 line number process control acc javacontainer routine waitforsubscanend short description unrecoverable error occur source object control array051 thread thread-33978 additional data javaex.class value alma controlexceptions.wrappers acsjfatalex usererrormessage value problem complete sub scan javaex.msg value error trace code type file datacollector.cpp host gas07 line number process control acc totalpower cppcontainer routine run short description general bulkdata error source object control array051 thread datacollector_uid://a002 xaebbcb x4bc2 additional data javaex.msg value javaex.class value alma.acs.exceptions defaultacsjexception error trace code type file tppbinaryblock.cpp host gas07 line number process control acc totalpower cppcontainer routine void tppbinaryblock::sendbinaryobject(totalpowersender corba::ulong short description action not perform source object control array051 thread datacollector_uid://a002 xaebbcb x4bc2 additional data javaex.msg value javaex.class value alma.acs.exceptions defaultacsjexception error trace code type file totalpowersender.cpp host gas07 line number process control acc totalpower cppcontainer routine void totalpowersender::startsend(corba::ulong const char size_t short description general bulkdata error source object control array051 thread datacollector_uid://a002 xaebbcb x4bc2 additional data javaex.msg value javaex.class value alma.acs.exceptions defaultacsjexception reason value fail start flow transference totalpowerstream6 totalpowerdataflow noformat',
#  'try measure band fe delay da47 repeatedly show bad result telcal consistent no coherence however look datum coherence phase vs. frequency rather crazy likely explain large telcal delay uncertainty fe lock fe status not very enlighten receiver performance point tune okay point jupiter look bb detector output telcalspy delay result example execution noformat delayreducedevent success execblockentityid uid://a002 x9aecaa x1b2 scan finishedat 18t05:22:34.761000 new result cal_delay full_resolution_cross scans startvalid 18t05:21:54.480000 endvalid 21t05:21:54.480000 duration ant da47 baseband bb_1 polar x band alma_rb_07 refant cm04 delay -2.593ns u ant da47 baseband bb_1 polar band alma_rb_07 refant cm04 delay -0.068ns u ant da47 baseband bb_2 polar x band alma_rb_07 refant cm04 delay -0.799ns u ant da47 baseband bb_2 polar band alma_rb_07 refant cm04 delay -1.018ns u ant da47 baseband bb_3 polar x band alma_rb_07 refant cm04 delay u ant da47 baseband bb_3 polar band alma_rb_07 refant cm04 delay -0.173ns u ant da47 baseband bb_4 polar x band alma_rb_07 refant cm04 delay -2.252ns u ant da47 baseband bb_4 polar band alma_rb_07 refant cm04 delay -1.360ns u noformat noformat sbex","2015 18t05:20:04 18t05:23:08","osf aos","2012.1.00180.csv","fe delay band 7","uid://a002 x9aecaa band=7","system","false","false noformat lot error like follow floog synchronisation control log da47 not obvious affect band noformat 18t05:56:25.165 control da47 floog virtual void floogimpl::processstatusmonitor(const monitorhelper::ambrequeststruct counted incorrect numb 125mhz clock cycle lead phase jump please check floog necessary switch invert clock set_clock_inversion command reset latch reset_fts_status command noformat']

# %% [markdown]
# #### Vectorize & TFIDF

# %%
#summary_corpus
summary_tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
summary_dtm_tf = summary_tf_vectorizer.fit_transform(summary_corpus)
summary_tfidf_vectorizer = TfidfVectorizer(**summary_tf_vectorizer.get_params())
summary_dtm_tfidf = summary_tfidf_vectorizer.fit_transform(summary_corpus)

#summary_dtm_tf
#summary_tfidf_vectorizer
#summary_dtm_tfidf

# %%
#description_corpus
description_tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
description_dtm_tf = description_tf_vectorizer.fit_transform(description_corpus)
description_tfidf_vectorizer = TfidfVectorizer(**description_tf_vectorizer.get_params())
description_dtm_tfidf = description_tfidf_vectorizer.fit_transform(description_corpus)

#description_dtm_tf
#description_tfidf_vectorizer
#description_dtm_tfidf

# %% [markdown]
# #### LDA MODEL

# %%
#summary_corpus
#for TF DTM
summary_lda_tf = LatentDirichletAllocation(n_components=3, random_state=0)
summary_lda_tf.fit(summary_dtm_tf)
# for TFIDF DTM
#lda_tfidf = LatentDirichletAllocation(n_components=4, random_state=1)
#lda_tfidf.fit(summary_dtm_tfidf)
# Out:
# LatentDirichletAllocation(n_components=3, random_state=0)

# %%
#description_corpus
#for TF DTM
description_lda_tf = LatentDirichletAllocation(n_components=3, random_state=0)
description_lda_tf.fit(description_dtm_tf)
# for TFIDF DTM
#lda_tfidf = LatentDirichletAllocation(n_components=4, random_state=1)
#lda_tfidf.fit(description_dtm_tfidf)
# Out:
# LatentDirichletAllocation(n_components=3, random_state=0)

# %% [markdown]
# #### Visualize Topics

# %%
#Prepare the visualization for summary_corpus
summary_prepared_data = pyLDAvis.sklearn.prepare(summary_lda_tf, summary_dtm_tf, summary_tf_vectorizer)
summary_prepared_data.topic_coordinates
# Out:
#               x         y  topics  cluster       Freq
# topic
# 2     -0.053779  0.111582       1        1  43.265627
# 0     -0.099555 -0.091384       2        1  32.138262
# 1      0.153334 -0.020198       3        1  24.596111

# %%
#Prepare the visualization for description_corpus
description_prepared_data = pyLDAvis.sklearn.prepare(description_lda_tf, description_dtm_tf, description_tf_vectorizer)
description_prepared_data.topic_coordinates
# Out:
#               x         y  topics  cluster       Freq
# topic
# 0      0.164240  0.170303       1        1  33.963208
# 1     -0.253996  0.036901       2        1  33.299989
# 2      0.089756 -0.207204       3        1  32.736803

# %%
#Summary_corpus 

summary_prepared_data.topic_coordinates['x'] = summary_prepared_data.topic_coordinates['x'].apply(lambda x: x.real)
summary_prepared_data.topic_coordinates['y'] = summary_prepared_data.topic_coordinates['y'].apply(lambda x: x.real)

pyLDAvis.display(summary_prepared_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.2.2/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el23369601398667531184166572397989"></div>
# <script type="text/javascript">
#
# var ldavis_el23369601398667531184166572397989_data = {"mdsDat": {"x": [-0.053779199748366105, -0.09955508625997286, 0.15333428600833893], "y": [0.1115816433443969, -0.0913840818703922, -0.020197561474004706], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [43.26562710977825, 32.13826154120665, 24.5961113490151]}, "tinfo": {"Term": ["lock", "bl", "ghz", "lo1", "datum", "high", "dv02", "pm04", "temperature", "cryostat", "da59", "pol", "trx", "issue", "aca", "failure", "phase", "suddenly", "correlation", "problem", "handover", "trec", "dv09", "mount", "cross", "freq", "wca3", "acacorr", "ape1", "temp", "mount", "low", "trx", "da63", "negative", "bl", "scan", "operational", "sb", "signal", "wait", "array", "encoder", "timeout", "pressure", "dv04", "dv10", "da43", "aos_bl_pr1", "b3", "science", "corr", "second", "sub", "timed", "dv13", "baseband", "lorr", "synchronize", "trouble", "fail", "tsys", "correlator", "da52", "little", "aos64", "antenna", "aos", "band", "ape1", "pol", "error", "aca", "ape2", "high", "dv17", "fe", "value", "el", "coherence", "power", "da59", "failure", "phase", "suddenly", "acu", "start", "receiver", "shutdown", "trec", "dv12", "stage", "cabin", "ambient", "hot", "dv16", "position", "shutter", "aos_aca_pr2", "cause", "stick", "acds", "da61", "ready", "sr", "subreflector", "rms", "da44", "aca7", "cm12", "flow", "temperature", "temp", "high", "aca", "pol", "aos", "dv07", "ape2", "ape1", "load", "band", "error", "antenna", "problem", "value", "acd", "ghz", "lo1", "lock", "dv02", "pm04", "cryostat", "datum", "correlation", "cross", "wca3", "freq", "acacorr", "107", "fe19", "b7", "bbpr2", "wca7", "alarm", "hvac", "service", "cm01", "strange", "dv18", "dv20", "degradation", "dv09", "band3", "issue", "failed", "total", "handover", "problem", "aos", "band", "power", "ape2", "cm04", "bl", "flag", "da45", "wrong", "node", "dv21"], "Freq": [27.0, 48.0, 10.0, 7.0, 6.0, 17.0, 5.0, 5.0, 10.0, 5.0, 6.0, 19.0, 12.0, 7.0, 18.0, 5.0, 5.0, 5.0, 4.0, 9.0, 10.0, 5.0, 5.0, 7.0, 3.0, 3.0, 3.0, 3.0, 14.0, 5.0, 6.9381446410269785, 6.067138192955472, 11.205303022881935, 4.427350190553612, 4.388865956544013, 42.21397047047527, 3.609198872464414, 3.608561492249798, 3.6071113556766163, 3.598486921891995, 2.779449406694949, 2.7793232872655143, 2.778947947255047, 2.7787338710180816, 2.7784542460616124, 2.7723700285416317, 2.769674869172511, 2.767853527184116, 2.7409794201102717, 2.7184755262763995, 2.6869231492791656, 2.686628454948912, 1.9455336316855123, 1.9455336316855123, 1.9455336316855123, 1.9452496402890054, 1.9451095463944554, 1.9449710649071228, 1.9449710649071228, 1.9449710649071228, 10.986797268682556, 7.605116217141574, 3.649401066731343, 3.630928610480579, 3.6090712972778087, 3.607206578226686, 7.510994943142853, 43.218425873829375, 19.24595012200808, 8.357935269301402, 8.76557829855644, 5.13768829741104, 7.71462505997432, 6.366905782294029, 5.842909992071517, 3.328430175332467, 3.6003250498667927, 3.5775791178489467, 2.8503304191764487, 2.818828156582227, 2.8741319002023267, 5.997845548915178, 5.209993739512751, 5.195260605330031, 5.194096757129561, 3.5684533562668768, 3.568234547534568, 3.564964354775111, 3.554793830664909, 4.961564789750479, 3.529040530652955, 2.745258128681518, 2.7450446629488967, 2.739412863756803, 2.7394128637567925, 2.732752254940684, 2.731725745659914, 2.7309794319682843, 2.717818667226072, 2.6635546454636065, 1.9214622040218954, 1.9214402325507236, 1.9214026577348442, 1.9214026577348442, 1.9214026577348442, 1.9214026577348442, 1.9213168540307506, 1.92128701369599, 1.921151158652423, 1.9211354456059042, 1.9210641180605204, 8.099354786842678, 4.243387712984054, 11.249177580139909, 10.151678300805647, 10.005856084340198, 25.028596926212995, 2.7322592464430664, 7.703572779164181, 6.275428527343766, 2.6749301022477967, 11.894576877084882, 3.7067901901325273, 3.7736020679121514, 3.192580751276647, 2.765859659604401, 2.7472571202979523, 9.525516230646454, 7.003207896362246, 25.565179423870216, 5.222024 ...

# %%
#Description_corpus 

description_prepared_data.topic_coordinates['x'] = description_prepared_data.topic_coordinates['x'].apply(lambda x: x.real)
description_prepared_data.topic_coordinates['y'] = description_prepared_data.topic_coordinates['y'].apply(lambda x: x.real)

pyLDAvis.display(description_prepared_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.2.2/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el23369601398667532598562882655442"></div>
# <script type="text/javascript">
#
# var ldavis_el23369601398667532598562882655442_data = {"mdsDat": {"x": [0.1642401951137467, -0.25399649067198354, 0.0897562955582368], "y": [0.1703031845629746, 0.03690106902719534, -0.2072042535901701], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [33.96320844686124, 33.29998886078494, 32.736802692353805]}, "tinfo": {"Term": ["dv21", "bb_3", "bb_1", "bb_2", "a002", "bb_4", "uid", "loggerthread", "ch", "info", "operational", "node", "cm04", "telcal", "incorrect", "flag", "value", "line", "load", "file", "javaex", "cdata", "stage", "stackid", "context", "logid", "cob", "cdpnode", "49", "usb", "loggerthread", "info", "incorrect", "cdata", "stackid", "context", "logid", "cob", "cdpnode", "peak", "offabs", "offrel", "width", "hot", "131", "checking", "site", "package", "ambient", "telcal", "132", "endexecution", "flag", "stacklevel", "min", "runsource", "traceback", "01t03", "mean", "01t11", "49", "err", "load", "cpn", "acssw", "2014", "dv11", "36", "line", "sourceobject", "file", "timestamp", "temperature", "corr", "process", "host", "routine", "thread", "time", "antenna", "error", "alma", "ch", "stage", "0x13l", "dbm", "usb", "mv", "_sis", "lsb", "loopv", "ua", "closed", "voltage", "operational", "ifproc", "ma", "cm01", "configured", "photomixer", "sideband", "ok", "mbar", "lpr", "da43", "selected", "_4k", "_110k", "_15k", "da65", "pll", "degraded", "node", "mode", "da57", "power", "pol", "band", "alma_rb_03", "noformat", "antenna", "sb", "coj", "status", "uid", "start", "a002", "bb_3", "dv21", "bb_1", "bb_2", "bb_4", "javaex", "baseband", "refant", "class", "spectral", "msg", "trace", "short", "additional", "number", "occur", "unrecoverable", "exceptions", "defaultacsjexception", "acsjfatalex", "cm04", "orbtask", "ccc", "10000l", "ssr", "great", "16l", "configuration", "invalid", "wrappers", "delay", "cm11", "da52", "da56", "usererrormessage", "dv22", "value", "a002", "da41", "uid", "data", "controlexceptions", "control", "acserr", "type", "error", "namevalue", "code", "polar", "alma", "band", "thread", "noformat", "process", "host", "ant", "routine", "file"], "Freq": [315.0, 313.0, 310.0, 302.0, 566.0, 298.0, 624.0, 299.0, 287.0, 272.0, 251.0, 356.0, 251.0, 242.0, 194.0, 205.0, 302.0, 334.0, 208.0, 398.0, 154.0, 156.0, 152.0, 153.0, 152.0, 151.0, 147.0, 144.0, 164.0, 140.0, 298.70465060319447, 271.8170627840586, 194.11832664435673, 155.74384324444935, 152.86757191746733, 151.91018959612717, 150.94932649852538, 147.1035280734765, 144.2341465985066, 105.85161300718647, 103.93801710676946, 103.93801710676946, 107.74532240868807, 95.30339361797364, 70.190350008395, 126.04286967214854, 53.888730381006425, 53.88869251881618, 106.81848273270752, 238.87498917836191, 35.80914319401643, 34.85935484629604, 201.43218869003758, 29.087510071227996, 28.130045554633732, 27.18273130954032, 27.146905424351594, 24.305595639553662, 24.30335591491708, 21.427324630419477, 158.08372921990778, 110.85892570704377, 198.95417717494163, 163.05893715208248, 85.22872464352918, 184.03029083220048, 178.4572583150967, 108.47229720291695, 271.3311034154924, 182.1454876288769, 296.64119666755914, 187.020636987698, 199.05144341381097, 179.18767077815966, 191.95732408619799, 186.46557513562786, 184.96014541106467, 193.2461238115099, 154.54768623871084, 213.78868530201467, 163.3897100755301, 131.4547086151961, 286.5296749033943, 152.06363391227967, 133.8199081046871, 131.80894372219709, 139.3918345729787, 98.27805708632101, 98.27805707481036, 111.61450405586851, 94.43656215950259, 94.43656215651451, 94.4365621550502, 94.41820339644082, 249.7860673491907, 79.06583958891186, 63.70531939342284, 75.09936464646995, 58.9050710248084, 58.901851845400664, 54.09797547845436, 54.088639317432836, 52.17682978243138, 51.2164349488654, 52.16486248977363, 51.21447329813995, 50.255633010868316, 50.25563300657989, 50.255633003781824, 50.18232871496552, 40.652599007862676, 39.68911112942703, 319.8844719992861, 120.1020740010307, 85.46633538938045, 109.53181822845599, 212.03361 ...
