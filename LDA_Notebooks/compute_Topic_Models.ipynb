# %% [markdown]
# ## Topic Modeling with pyLDAvis

# %%
#Cleaning of text column completed before this step using Dataiku Text Preparation Plugin
#Resources: https://towardsdatascience.com/end-to-end-topic-modeling-in-python-latent-dirichlet-allocation-lda-35ce4ed6b3e0
#https://towardsdatascience.com/topic-model-visualization-using-pyldavis-fecd7c18fbf6

# %%
#Import Libraries
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu

import os

import pyLDAvis.gensim
import pickle 
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

#hide warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Read recipe inputs
Text_Cleaned = dataiku.Dataset("Text_Cleaned")
Text_Cleaned_df = Text_Cleaned.get_dataframe()
Text_Cleaned_df
# Out:
#   SE_DOWNTIMETYPE                          SE_SUBJECT_concat_cleaned
# 0           Other  pr bl da63 control cppcontainer go shutdown pr...
# 1      Scheduling  bl ape2 tp statistic waiting end execution inc...
# 2       Technical  slt test please ignore pr bl totalpowerprocess...
# 3         Weather  bad wather bad weather bad weather shutdown ac...

# %%
# Extract text column as a list
text_list = Text_Cleaned_df['SE_SUBJECT_concat_cleaned'].tolist()
# Corpus as a list of text documents
corpus_full = [' '.join(text.split()) for text in text_list]

# %%
corpus_full
# Out:
# ["pr bl da63 control cppcontainer go shutdown pr bl failed activate component control array001 totalpowerprocessor',pr bl interferometric point fail getinterferometryoffshoot alma-10_6_0-b-2014 00,pr6 tp not work fdm acs cm05 container crash array dv08 mount subreflector power failure pr1 bl correlator resource conflict receive callbacks expect 3',other da62 high tsys value da58 not lock band7,other da47 not lock band7,pr1 bl correlator resource conflict receive callbacks expect 3',pr1 bl corr cdp_node n16 lp fail stop continue stop sequence ,other dv06 sudden servo failure axis ,other da47 fail lock band 6.,other cm03 cm05 cm12 cm07 container crash time handover control go error dv09 fe wca3 show weird status failed activate component control array /totalpowerprocessor tfint pm01 beam distortion pr1 bl correlator resourse conflict value exception throw clustercommander.cpp:244 little node fail execute method startsubscansequence),other dv06 acd little motor not position',other da49 acu not reachable ccl handover control bl aca subsystem come error ,other dv06 el encoder error handover dv06 dv10 high hl temp warn da59 psd go shutdown pr1 bl subscan not stop second -correlator resource conflict pr4 aca not complete subscan sequence error invoke observe mode function general bulkdata error aos bl timeout aos remote work da52 jcastillo",
#  'bl ape2 tp statistic waiting end execution include pm antenna aca array waiting min right time start time constrained project 2017.a.00035.s/3fgl_j04_a_06_tm1,waiting ddt project ,vir continuous bad weather vir continuous bad weather wait finish include tp array cai aca tp without project antennas bl),waiting time critical observation 01:30utc no time schedule ,queue gap shift end shift end queue gap shift end shift end ape2 tp scheduling time queue gap),no project aca tp aca_tp test start 22:00:00ut queue gap no project aca tp aca_tp shift ending scheduling downtime no tp project eoc project test flag set ape2 tp statistics scheduling queue gap no pi science projects),shift ending shift ending queue gap queue gap queue gap aca tp queue gap shift ending shift ending queue gap queue gap waiting project queue gap waiting project queue gap waiting project queue gap waiting project shift end waiting project shift ending shift ending no tp project available queue gap aca tp no project available waiting project shift end queue gap wating observatory calibrations no project fo tp queue gap queue gap queue gap queue gap queue gap planned sky execute shift end shift end shift end no sbs run wait shift finish wait time window grid survey antennas move integration not enough antenna science no sbs run end shift end shift no sbs run end shift shift end shift end shift end end shift queue gap tp antenna bl array queue gap shift end no science project tp nothing run nothing observe shift ending shift ending no science porjects tp acatp waiting project pms move antenna integration bl array aca tp waiting project",the astronomer work pm01 pm02 eoc test end shift end shift no project available tp array end shift shift ending no observable project no project available shift end shift end science plan change perform observatory calibratins antenna bl array no project available queue gap aca tp sheduling downtime aca tp sheduling downtime nothing run no project available tp array queue gap queue gap no project available end shift queue gap nothing dsa cms antenna bl no project available tp array nothing dsa pms antenna bl no project dsa no science project tp nothing observe queue gap nothing dsa observe ,scheduling downtime aca tp not sb dsa aca tp no project dsa sched nothing observe end shift queue gap nothing dsa nothing dsa waiting cms antenna bl cms antenna bl queue gap nothing dsa no project observe shift ending shift ending no science prject tp no project available current atmosphere condition no project available not project tp no project dsa end shift end shift no project available current atmosphere condition no project observe scheduling downtime tp pms antennas),array recreation take extra time time spend make decision weather station configuration update no project available current atmosphere condition endshift shift ending no project observe no project observe no project observe aca tp pms no science project observe look project waiting science obs finish order associate weather station,(for statistic bl alarm look suitable project ,no science project tp no project observe no project observe no project observe no project observe no project available current atmosphere condition no tp project available aca restart no project no project queue gap looking project queue gap end shift bad weather high phase rms wait pm antenna integrate array queue gap no tp project available no project available shift ending queue gap tp no project tp no project available tp current atmosphere condition no project science remain time shift ending no tp project available no project available current atmosphere condition queue gap wait end shift no project available current atmosphere condition queue gap tp no project end shift gap nothing observe aca tp array pms move bl array creation take long ,aca_tp no band project check gonogo array creation pms acatp previous observation abort switch eoc pi observations array creation antennas integrate bl pi ob ...
#  'slt test please ignore pr bl totalpowerprocessor datacollector error attempt send datum bulkdatareceiver pr1 bl error invoke observe mode pr1 bl da58 not lock b7,other ql focus result not display quicklook spite display telcal da65 drxbbpr3 stop dv17 bbp4 wrong metaframedelay dv08 b7 large/ negative trec value poly pr1 bl dv01 acu not canbus handover da56 not send lo2bbpr0 operational handover bl drxbbpr0 come start antenna pr1 bl error invoke observe mode function timed wait second correlator start sub scan \',other da52 timeout wait connection ifproc datareceiver pr1 bl dv06 displacement sensor redout error high value linear sensor handover da58 el drive not initialize brake disengage time da56 lo2bbpr0 stick stop state pr1 bl da61 drx3 count different value metaframe delay handover da52 shutting digitizer da52:0 processor label da520 not connect ,other da56 baseband bb_1 polar band alma_rb_03 refant cm01 delay u aos bl pr1 da56 high receiver cabin temperature ,pr1 bl dv08 b7 large/ negative trec value poly pr bl cm12 antenna el az drive go shutdown pr1 bl correlator resource conflict datum cluster master node time handover clo antenna come problem synchronize lorr handover da45 lorr trouble synchronize scheduler unable create new array pr1 bl control dmc4 cppcontainer gl crash dv04 subreflector actuator not pr1 bl prtspr-8757,pr1 bl prtsir-4307 prtsir-4308,pr1 bl prtspr-8778,other handover aca acacorr cdp_data_mgr n20 cppcontainer not start dv13 da46 no fe handover da58 receiver cabin warm pr1 bl error invoke observe mode function- timed wait second correlator archive sub scan dv10 ups alarm control master error create automatic array component dv13 pdu not available dv16 compressor alarm feps not available archive go error dv21 wca7 error pr1 bl timed wait second correlator start sub scan \',pr1 bl error start execution get observe mode instance invalid array error define array correlator ,other da48 lpr configure da54 delay u pr1 da43 not lock b4,pr1 bl prtspr-8755,pr1 bl dv08 b7 large/ negative trec value poly pr1 bl da58 not lock band 7,dv21 cm09 not lock band 3,pr1 bl,5 llc stop prtspr-2212,ls take long tols take long lock make sb fail error got late sequence thread late xxx seconds pr2 aca pr1 bl correlator go error prtspr-2250,aos bl corr cdp_master_thread_0 datum not arrive time aos blcorr corr cdpmaster cppcontainer gl exception throw /include blobstreamer.i:214 current blob not match abort aos blcorr cdp_master_thread_0 datum not arrive time aos sbex fail error control da43 cppcontainer gl illegal parameter error aos control totalpower cppcontainer suddenly crash sbs ,other no observe mode aca dv01 brake engage aos aca pr2 q2 cdpmaster prtspr-2574,aos aca pr2 pm01 prtspr-2572,pr1 bl dv05 control container crash prtspr-2427,prtspr-2428 aca observation control container problem prtspr-2429 total power array observation problem pr1 bl dv08 prtspr-2447,pr4 aca yellow triangle prtspr-2448,bad weather prtspr-2060 antenna survival stow da59 high system temperature ,other dv19 failed lock band 7,pr aca not calibrate correlator pr bl da43 rec cabin temperature alarm pr bl da63 base interlock active aos acs lose connectivity database prtspr-3330),aos dv19 b6 poly show high tsys trx other:,pr1 bl pr1 bl pr1 bl pr bl pr bl aca error get reference alma control totalpowerhelper component differents antenna aos dv23 doesn\'t lock band 9,pr1 bl da48 antenna soft localcpu pr bl pr1 bl pr1 bl aos dv19 timed go source ,prtspr-2300,prtspr-2301,handover aos da59 hvac not start handover aos da57 utility module estop active other:,other:,pr1 bl aos bl observation crash try create totalpower array ,other aos crc-01 console disk space 99%,other:,dv25 not moveable dv01 go shutdown pr1 bl pr1 bl aos control acc totalpower cppcontainer description container aos dv10 band fail lock 1stlo ghz clone aos da49 not specify total power processor consume datum antenna da49,other aos pr1 ssr configuration know bug ,prtspr-2833,prtspr-2834,clone aos ...
#  'bad wather bad weather bad weather shutdown active aos snow chajnantor aos guard call snow highsite ,no cloud camera restart slush snowing guard call light precipitation high site light snow hight site report guard no observation science downtime snowing lightning rain cloudy antennas send survival position ,rain snow bad weather high site snowing again false alarm snow camera light snow snow camera minute far snow bad weather snowing electrical storm),bad weather snow aos white wind aos pr bl dv07 didd\'t lock band 3,bad weather no observations bad weather condition no observation pwr very inastable night ,aos precipitatin high site precipitation aos snowing aos snow aos bad weather bad weather bad weather strong wind wait visual inspection sky bad weather waiting good condition visual inspection weather observation stop bad weather scheduler internal exception control creation array pr2 bl sbex cdpm ptherad mutex timeout bad weather water vapor mm no project availables ,pr aca correlator not clear configuration calibration prevent subsequent use correlator pr bl aos blcorr science sb fail scan fail lock wca antenas lo1 frequency pr#2,high wind aos bad entry pr1 bl invalid array error define array correlator high wind visual inspection required pr aca aos aca sciece sb fail cm06 cppcontainer go shutdown segmentation fault" ,high wind aos register meteo 4,pr bl aos bl science sb fail scan exception throw bulkdatasender fail start flow transference ,snow aos bad weather hr bad weather array cover cloud humid guards call snow high site snowing aos aos dv16 cryo alarm bad weather snow aos aos snow pr1 bl aos error invoke observe mode function subscan not stop second dv01 hvac alarm pr1 bl correlator resource conflict pr4 aos2 aca error invoke observe mode function- observation not provide little starttime snowing high site precipitation hight site weather wvr band 6),high pwv high phase noise large path length fluctuantions precipitation,==finished==bad weather snowing),pecipitation snowing aos weather downtime bl observations,==visual inspection==bl downtime pwv electric storm bad weather pwv mm!,pwv high 3mm),bad weather aos bad weather high site pr bl no project available weather condition pr bl no project available weather condition pr bl bad weather pwv value mm very unstable phase pr1 bl bad weather no band project pr3 aca bad weather no band project pr1 bl bad weather unstable phase pr1 bl bad weather unstable phase bad wather mounts simulation high humidity wvr mm high humidity pwv mm path length fluctuation 2000um pwv mm unstable condition pwv mm unstable condition no low freq sbs pwv mm unstable condition pwv mm unstable condition pwr especifications observe precipitation high site aca weather downtime pr1 bl pwv mm],pr4 aca pwv mm],pr4 aca pwv mm],snowing aos wind poor pwr phase stability snowing aos unstable condition bad weather bad weather snow wind need visual inspection high wind speed meteo sensor aos high s),pwr fluctuation 4mm),aos precipitations bl badweather strong wind m/s wait h below limit snow aos requires visual inspection day high wind condition meteo1 pm antenna slight snow bad wheather unstable high pwv unstable high pwv precipitation wind strong wind no chance visual inspection mount simulation cycle3on weather downtime aca aca windy s],=== bad weather downtime==,snowing aos high wind aos aos snow fall bl pr1 pwv wind speed wait h below limit snow high winds wind speed meteocentral wind speed meteocentral m/s wind speed meteo central wind speed meteocentral wind speed red flag i.e. wind speed aos wind wind speed high wind meteocentral meteo309,high wind high wind meteocentral wind speed central cluster+inner array survival stow wind speed meteocentral wind wind speed meteocentral meteo309 meteo410),winds detect meteocentral aos weather downtime meteocentral high winds s],high winds s],high wind central cluster antenna extend configuration high wind s],test ict-5560,test weather downtime ict-5560,te ...

# %%
len(corpus_full)
# Out:
# 4

# %% [markdown]
# #### Vectorize & TFIDF

# %%
#tf_vectorizer = CountVectorizer(strip_accents = 'unicode',
#                                stop_words = 'english',
#                                lowercase = True,
#                                token_pattern = r'\b[a-zA-Z]{3,}\b',
#                                max_df = 0.95, 
#                                min_df = 1)

tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
dtm_tf = tf_vectorizer.fit_transform(corpus_full)
tfidf_vectorizer = TfidfVectorizer(**tf_vectorizer.get_params())
dtm_tfidf = tfidf_vectorizer.fit_transform(corpus_full)

# %%
#dtm_tf
#tfidf_vectorizer
#dtm_tfidf

# %% [markdown]
# #### LDA Model

# %%
# for TF DTM
lda_tf = LatentDirichletAllocation(n_components=4, random_state=0)
lda_tf.fit(dtm_tf)
# for TFIDF DTM
#lda_tfidf = LatentDirichletAllocation(n_components=4, random_state=1)
#lda_tfidf.fit(dtm_tfidf)
# Out:
# LatentDirichletAllocation(n_components=4, random_state=0)

# %% [markdown]
# #### Vizualize Topics

# %%
# define a dictionary of topic names
topic_names = {
    1: 'Technical',
    2: 'Weather',
    3: 'Scheduling',
    4: 'Other'
}

# %%
#Prepare the visualization
prepared_data = pyLDAvis.sklearn.prepare(lda_tf, dtm_tf, tf_vectorizer)
#prepared_data.topic_coordinates.rename(index={0: 'Other', 2: 'Scheduling', 3: 'Technical', 1: 'Weather'}, inplace=True)

# map the topic numbers to their corresponding names
#prepared_data.topic_coordinates['topics'] = prepared_data.topic_coordinates['topics'].map(topic_names)

prepared_data.topic_coordinates
# Out:
#               x         y  topics  cluster       Freq
# topic
# 3     -0.220100  0.011012       1        1  71.935173
# 1      0.161453  0.214129       2        1  20.826245
# 2      0.157851 -0.211951       3        1   7.234990
# 0     -0.099204 -0.013190       4        1   0.003591

# %%
prepared_data.topic_coordinates['x'] = prepared_data.topic_coordinates['x'].apply(lambda x: x.real)
prepared_data.topic_coordinates['y'] = prepared_data.topic_coordinates['y'].apply(lambda x: x.real)

pyLDAvis.display(prepared_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.2.2/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el13379421406076761864486033501503"></div>
# <script type="text/javascript">
#
# var ldavis_el13379421406076761864486033501503_data = {"mdsDat": {"x": [-0.22009960241093826, 0.16145300734216586, 0.1578510574160492, -0.09920446234727655], "y": [0.011011908601603185, 0.21412929177293472, -0.21195076144379082, -0.013190438930747], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [71.93517332521812, 20.826245245599008, 7.23499010070406, 0.0035913284788053404]}, "tinfo": {"Term": ["project", "wind", "aos", "weather", "speed", "pr1", "bad", "pr", "issue", "pr4", "end", "antenna", "available", "correlator", "crash", "shift", "power", "pr2", "corr", "pr3", "container", "control", "scan", "condition", "failure", "snow", "precipitation", "problem", "prtspr", "cppcontainer", "crash", "power", "container", "failure", "subsystem", "issue", "acs", "receive", "pr4", "pr2", "pr3", "el", "tsys", "control", "dv10", "acd", "psd", "component", "cppcontainer", "recovery", "da49", "corr", "pr1", "failed", "dv09", "node", "fsr", "correlator", "cm05", "scan", "pr", "problem", "prtspr", "second", "timeout", "subscan", "sub", "point", "cai", "axis", "shutdown", "stop", "sb", "restart", "delay", "set", "aos", "antenna", "wait", "precipitation", "wind", "speed", "vir", "snowing", "pwv", "winds", "trigger", "snow", "site", "visual", "inspection", "dish", "mm", "meteo", "wheather", "rms", "meteocentral", "meteotb2", "survival", "sun", "weather", "rm", "strong", "survivor", "nogo", "condition", "tb2", "alert", "fluctuation", "stow", "pend", "phase", "bad", "pm", "pms", "downtime", "aos", "alarm", "antenna", "observation", "project", "affect", "waiting", "wait", "available", "shift", "gap", "remaining", "project", "currently", "sheduling", "end", "scheduling", "queue", "campaign", "protocol", "proyect", "projets", "waitng", "continuous", "projects", "min", "solar", "choose", "eoc", "remain", "current", "run", "available", "activity", "object", "plan", "lt", "pwm", "addition", "atmosphere", "waiting", "vlbi", "dsa", "science", "finish", "order", "condition", "eng", "idle", "aca_tp", "downtime", "antenna", "wait", "weather", "observation", "antennas", "pms", "test", "pm", "start", "lt", "pwm", "addition", "calibrations", "final", "fo", "happen", "kill", "planned", "survey", "urgent", "waitign", "witing", "xyz", "59", "afer", "bulkdatasender", "extend", "face", "fot", "needed", "requirement", "wnt", "40", "sttoped", "subsequent", "um", "10_6_0", "array001", "beam", "00", "2014", "cdp_node", "n16", "totalpowerprocessor", "fdm", "getinterferometryoffshoot", "interferometric", "resourse", "band7", "244", "pr6", "remote", "callbacks", "startsubscansequence", "warn", "clustercommander", "wca3", "little", "activate", "tfint", "expect", "come", "weird", "dv06", "ccl", "position"], "Freq": [742.0, 924.0, 1273.0, 509.0, 341.0, 1358.0, 373.0, 983.0, 634.0, 642.0, 157.0, 783.0, 187.0, 562.0, 299.0, 118.0, 242.0, 273.0, 298.0, 257.0, 204.0, 219.0, 245.0, 194.0, 171.0, 159.0, 151.0, 240.0, 266.0, 185.0, 299.43823179859675, 241.78705355110202, 204.01558974234067, 171.2140562930915, 157.29825605949839, 632.4241680680749, 99.6470759402934, 98.65308701785398, 639.3820446264402, 271.6069531657526, 255.70316053881476, 83.74330184354959, 81.75533006557055, 217.93163936526773, 71.81547110205624, 65.85155564892868, 63.86358381518594, 62.86959309965687, 184.13609047828965, 180.16014556222666, 58.89365418799454, 296.4565864998377, 1347.100579556898, 165.2503010403008, 54.91771043333091, 52.92973853468438, 156.30443227637335, 556.8810957726788, 48.953788513374164, 242.78129618389713, 973.361545510765, 237.81164102242224, 262.66130830024264, 141.3946468116886, 140.4006597425271, 125.49084888661591, 121.51491025214233, 147.35854547947903, 114.55698193897211, 114.55699576060512, 232.84134982106556, 206.00370345346, 241.787407665195, 125.49098518035322, 134.43668253410894, 157.29854125570088, 816.3096314656477, 539.9826770013163, 230.85329022565855, 150.16423821443755, 904.6593247940865, 332.4188145252978, 116.8456438425909, 45.3187100790168, 69.81399274926504, ...

# %%
# Write recipe outputs
Topic_Modeling3 = dataiku.Dataset("Topic_Modeling3")
#Topic_Modeling3.write_with_schema(Topic_Modeling3_df)
